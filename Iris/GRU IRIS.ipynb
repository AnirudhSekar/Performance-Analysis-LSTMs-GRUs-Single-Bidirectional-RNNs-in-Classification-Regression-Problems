# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU
import tensorflow as tf
import os
import seaborn as sns
from sklearn.model_selection import train_test_split
from timeit import default_timer as timer

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
df = pd.read_csv("../Iris.csv")
df.replace(to_replace="Iris-setosa", value=0, inplace=True)
df.replace("Iris-versicolor", 1, inplace=True)
df.replace("Iris-virginica", 2, inplace=True)
df.head()
# Out:
# /var/folders/8_/t3znlm6s3n1gdhfwvmxv3gp40000gn/T/ipykernel_67041/1182936694.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace("Iris-virginica", 2, inplace=True)
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
X = df[df.columns[:len(df.columns)-1]]
y = df["Species"]

scaler = MinMaxScaler(feature_range=(0,1))
X = scaler.fit_transform(np.array(X))
X = np.reshape(X, (X.shape[0], X.shape[1], 1))
x_train, x_test, y_train, y_test = train_test_split(X, y, train_size=0.8)

# %%
f1 = []
log_loss = []  
accuracy = []
class PredictionCallback(tf.keras.callbacks.Callback):    
  def on_epoch_end(self, epoch, logs={}):
    y_pred = self.model.predict(x_test)
    index = []
    for array in y_pred:
        for i in range(len(array)):
            if max(array, key=lambda x: x) == array[i]:
                index.append(i)

    # Evaluate the model on training and testing data
    f1.append(metrics.f1_score(y_test, index , average='micro'))
    log_loss.append((metrics.log_loss(y_test, y_pred)))
    accuracy.append(metrics.balanced_accuracy_score(y_test, index))

# %%
class Model_Timer(tf.keras.callbacks.Callback):
    def __init__(self):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

# %%
model = Sequential([
    GRU(50,return_sequences=True),
    GRU(50,return_sequences=True),
    GRU(50,return_sequences=True),
    GRU(50),
    Dense(3, activation="softmax")
])
cb = Model_Timer()
# Compile the model
model.compile(optimizer=tf.optimizers.legacy.Adam(learning_rate=0.001), loss="sparse_categorical_crossentropy", metrics=["accuracy", "MeanAbsoluteError","RootMeanSquaredError", "MeanSquaredError"])
model.fit(x_train, y_train, batch_size=8, epochs=25, validation_data=(x_test, y_test),callbacks=[PredictionCallback(), cb])
# Out:
# Epoch 1/25
# 1/1 [==============================] - 0s 477ms/steploss: 1.1013 - accuracy: 0.3750 - mean_absolute_error: 0.7917 - root_mean_squared_error: 0.9502 - mean_squared_error: 0.90
# 15/15 [==============================] - 3s 96ms/step - loss: 1.0925 - accuracy: 0.3167 - mean_absolute_error: 0.8694 - root_mean_squared_error: 1.0346 - mean_squared_error: 1.0704 - val_loss: 1.0419 - val_accuracy: 0.4000 - val_mean_absolute_error: 0.9667 - val_root_mean_squared_error: 1.1315 - val_mean_squared_error: 1.2803
# Epoch 2/25
# 1/1 [==============================] - 0s 9ms/step loss: 1.1322 - accuracy: 0.1250 - mean_absolute_error: 0.5833 - root_mean_squared_error: 0.7275 - mean_squared_error: 0.52
# 15/15 [==============================] - 0s 5ms/step - loss: 1.0240 - accuracy: 0.4667 - mean_absolute_error: 0.8694 - root_mean_squared_error: 1.0353 - mean_squared_error: 1.0718 - val_loss: 0.9191 - val_accuracy: 0.6667 - val_mean_absolute_error: 0.9667 - val_root_mean_squared_error: 1.1333 - val_mean_squared_error: 1.2843
# Epoch 3/25
# 1/1 [==============================] - 0s 9ms/step loss: 1.0012 - accuracy: 0.5000 - mean_absolute_error: 0.6250 - root_mean_squared_error: 0.7568 - mean_squared_error: 0.57
# 15/15 [==============================] - 0s 5ms/step - loss: 0.7351 - accuracy: 0.7167 - mean_absolute_error: 0.8694 - root_mean_squared_error: 1.0531 - mean_squared_error: 1.1089 - val_loss: 0.4695 - val_accuracy: 0.8333 - val_mean_absolute_error: 0.9667 - val_root_mean_squared_error: 1.1748 - val_mean_squared_error: 1.3801
# Epoch 4/25
# 1/1 [==============================] - 0s 8ms/step loss: 0.4033 - accuracy: 0.8750 - mean_absolute_error: 0.7500 - root_mean_squared_error: 0.9776 - mean_squared_error: 0.95
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4536 - accuracy: 0.7667 - mean_absolute_error: 0.8694 - root_mean_squared_error: 1.0958 - mean_squared_error: 1.2008 - val_loss: 0.3620 - val_accuracy: 0.8000 - val_mean_absolute_error: 0.9667 - val_root_mean_squared_error: 1.1948 - val_mean_squared_error: 1.4275
# Epoch 5/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.3914 - accuracy: 0.8750 - mean_absolute_error: 0.8750 - root_mean_squared_error: 1.1523 - mean_squared_error: 1.32
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2735 - accuracy: 0.9167 - mean_absolute_error: 0.8694 - root_mean_squared_error: 1.0994 - mean_squared_error: 1.2087 - val_loss: 0.2867 - val_accuracy: 0.8667 - val_mean_absolute_error: 0.9667 - val_root_mean_squared_error: 1.1948 - val_mean_squared_error: 1.4275
# Epoch 6/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.1987 - accuracy: 0.8750 - mean_absolute_error: 0.7917 - root_mean_squared_error: 1.0251 - mean_squared_error: 1.05
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1981 - accuracy: 0.9250 - mean_absolute_error: 0.8694 - root_mean_squared_error: 1.1150 - mean_squared_error: 1.2432 - val_loss: 0.2031 - val_accuracy: 0.9333 - val_mean_absolute_error: 0.9667 - val_root_mean_squared_error: 1.2096 - val_mean_squared_error: 1.4630
# Epoch 7/25
# 1/1 [==============================] - 0s 10ms/steploss: 0.0322 - accuracy: 1.0000 - mean_absolute_error: 0.8333 - root_mean_squared_error: 1.0708 - mean_squared_error: 1.14
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2113 - accuracy: 0.9250 - mean_absolute_error: 0.8694 - root_mean_squared_error: 1.1218 - mean_squared_error: 1.2585 - val_loss: 0.2357 - val_accuracy: 0.9333 - val_mean_absolute_error: 0.9667 - val_root_mean_squared_error: 1.2090 - val_mean_squared_error: 1.4617
# Epoch 8/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0198 - accuracy: 1.0000 - mean_absolute_error: 0.7917 - root_mean_squared_error: 1.0550 - mean_squared_error: 1.11
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2237 - accuracy: 0.9167 - mean_absolute_error: 0.8694 - root_mean_squared_error: 1.1204 - mean_squared_error: 1.2554 - val_loss: 0.2051 - val_accuracy: 0.9333 - val_mean_absolute_error: 0.9667 - val_root_mean_squared_error: 1.2094 - val_mean_squared_error: 1.4626
# Epoch 9/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.1075 - accuracy: 1.0000 - mean_absolute_error: 0.7917 - root_mean_squared_error: 1.0375 - mean_squared_error: 1.07
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1908 - accuracy: 0.9500 - mean_absolute_error: 0.8694 - root_mean_squared_error: 1.1207 - mean_squared_error: 1.2559 - val_loss: 0.1649 - val_accuracy: 0.9667 - val_mean_absolute_error: 0.9667 - val_root_mean_squared_error: 1.2110 - val_mean_squared_error: 1.4666
# Epoch 10/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0188 - accuracy: 1.0000 - mean_absolute_error: 0.7917 - root_mean_squared_error: 1.0550 - mean_squared_error: 1.11
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1366 - accuracy: 0.9667 - mean_absolute_error: 0.8694 - root_mean_squared_error: 1.1236 - mean_squared_error: 1.2624 - val_loss: 0.2136 - val_accuracy: 0.9333 - val_mean_absolute_error: 0.9667 - val_root_mean_squared_error: 1.2105 - val_mean_squared_error: 1.4654
# Epoch 11/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.2245 - accuracy: 0.8750 - mean_absolute_error: 0.8333 - root_mean_squared_error: 1.0606 - mean_squared_error: 1.12
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1816 - accuracy: 0.9333 - mean_absolute_error: 0.8694 - root_mean_squared_error: 1.1254 - mean_squared_error: 1.2665 - val_loss: 0.1674 - val_accuracy: 0.9333 - val_mean_absolute_error: 0.9667 - val_root_mean_squared_error: 1.2111 - val_mean_squared_error: 1.4667
# Epoch 12/25
# 1/1 [==============================] - 0s 11ms/steploss: 0.1231 - accuracy: 1.0000 - mean_absolute_error: 0.8750 - root_mean_squared_error: 1.0790 - mean_squared_error: 1.16
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1689 - accuracy: 0.9417 - mean_absolute_error: 0.8694 - root_mean_squared_error: 1.1241 - mean_squared_error: 1.2637 - val_loss: 0.1967 - val_accuracy: 0.9333 - val_mean_absolute_error: 0.9667 - val_root_mean_squared_error: 1.2141 - val_mean_squared_error: 1.4741
# Epoch 13/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.3129 - accuracy: 0.8750 - mean_absolute_error: 0.9583 - root_mean_squared_error: 1.1960 - mean_squared_error: 1.43
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1601 - accuracy: 0.9417 - mean_absolute_error: 0.8694 - root_mean_squared_error: 1.1237 - mean_squared_error: 1.2627 - val_loss: 0.3016 - val_accuracy: 0.9000 - val_mean_absolute_error: 0.9667 - val_root_mean_squared_error: 1.2077 - val_mean_squared_error: 1.4585
# Epoch 14/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0215 - accuracy: 1.0000 - mean_absolute_error: 0.6250 - root_mean_squared_error: 0.8823 - mean_squared_error: 0.77
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1803 - accuracy: 0.9167 - mean_absolute_error: 0.8694 - root_mean_squared_error: 1.1241 - mean_squared_error: 1.2635 - val_loss: 0.2277 - val_accuracy: 0.9333 - val_mean_absolute_error: 0.9667 - val_root_mean_squared_error: 1.2136 - val_mean_squared_error: 1.4728
# Epoch 15/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0165 - accuracy: 1.0000 - mean_absolute_error: 0.5833 - root_mean_squared_error: 0.8599 - mean_squared_error: 0.73
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1495 - accuracy: 0.9500 - mean_absolute_error: 0.8694 - root_mean_squared_error: 1.1260 - mean_squared_error: 1.2679 - val_loss: 0.1599 - val_accuracy: 0.9333 - val_mean_absolute_error: 0.9667 - val_root_mean_squared_error: 1.2122 - val_mean_squared_error: 1.4693
# Epoch 16/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0359 - accuracy: 1.0000 - mean_absolute_error: 1.2500 - root_mean_squared_error: 1.4367 - mean_squared_error: 2.06
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1319 - accuracy: 0.9417 - mean_absolute_error: 0.8694 - root_mean_squared_error: 1.1229 - mean_squared_error: 1.2609 - val_loss: 0.1777 - val_accuracy: 0.9333 - val_mean_absolute_error: 0.9667 - val_root_mean_squared_error: 1.2102 - val_mean_squared_error: 1.4647
# Epoch 17/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0157 - accuracy: 1.0000 - mean_absolute_error: 0.5417 - root_mean_squared_error: 0.7291 - mean_squared_error: 0.53
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1877 - accuracy: 0.9333 - mean_absolute_error: 0.8694 - root_mean_squared_error: 1.1243 - mean_squared_error: 1.2640 - val_loss: 0.2436 - val_accuracy: 0.9333 - val_mean_absolute_error: 0.9667 - val_root_mean_squared_error: 1.2140 - val_mean_squared_error: 1.4737
# Epoch 18/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.1077 - accuracy: 1.0000 - mean_absolute_error: 0.9583 - root_mean_squared_error: 1.1901 - mean_squared_error: 1.41
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1717 - accuracy: 0.9417 - mean_absolute_error: 0.8694 - root_mean_squared_error: 1.1233 - mean_squared_error: 1.2618 - val_loss: 0.1752 - val_accuracy: 0.9333 - val_mean_absolute_error: 0.9667 - val_root_mean_squared_error: 1.2089 - val_mean_squared_error: 1.4614
# Epoch 19/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.2377 - accuracy: 0.8750 - mean_absolute_error: 1.2917 - root_mean_squared_error: 1.4442 - mean_squared_error: 2.08
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1824 - accuracy: 0.9333 - mean_absolute_error: 0.8694 - root_mean_squared_error: 1.1240 - mean_squared_error: 1.2634 - val_loss: 0.1970 - val_accuracy: 0.9333 - val_mean_absolute_error: 0.9667 - val_root_mean_squared_error: 1.2111 - val_mean_squared_error: 1.4667
# Epoch 20/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0361 - accuracy: 1.0000 - mean_absolute_error: 0.6667 - root_mean_squared_error: 0.9011 - mean_squared_error: 0.81
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1205 - accuracy: 0.9583 - mean_absolute_error: 0.8694 - root_mean_squared_error: 1.1239 - mean_squared_error: 1.2631 - val_loss: 0.2821 - val_accuracy: 0.9000 - val_mean_absolute_error: 0.9667 - val_root_mean_squared_error: 1.2069 - val_mean_squared_error: 1.4566
# Epoch 21/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.4642 - accuracy: 0.8750 - mean_absolute_error: 0.6667 - root_mean_squared_error: 0.8903 - mean_squared_error: 0.79
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1822 - accuracy: 0.9417 - mean_absolute_error: 0.8694 - root_mean_squared_error: 1.1236 - mean_squared_error: 1.2626 - val_loss: 0.1835 - val_accuracy: 0.9333 - val_mean_absolute_error: 0.9667 - val_root_mean_squared_error: 1.2102 - val_mean_squared_error: 1.4645
# Epoch 22/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0293 - accuracy: 1.0000 - mean_absolute_error: 0.7083 - root_mean_squared_error: 0.9260 - mean_squared_error: 0.85
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1253 - accuracy: 0.9500 - mean_absolute_error: 0.8694 - root_mean_squared_error: 1.1249 - mean_squared_error: 1.2653 - val_loss: 0.2657 - val_accuracy: 0.9000 - val_mean_absolute_error: 0.9667 - val_root_mean_squared_error: 1.2109 - val_mean_squared_error: 1.4663
# Epoch 23/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.3412 - accuracy: 0.8750 - mean_absolute_error: 0.8750 - root_mean_squared_error: 1.0784 - mean_squared_error: 1.16
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2291 - accuracy: 0.9167 - mean_absolute_error: 0.8694 - root_mean_squared_error: 1.1233 - mean_squared_error: 1.2619 - val_loss: 0.1971 - val_accuracy: 0.9333 - val_mean_absolute_error: 0.9667 - val_root_mean_squared_error: 1.2153 - val_mean_squared_error: 1.4769
# Epoch 24/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.4940 - accuracy: 0.8750 - mean_absolute_error: 0.6667 - root_mean_squared_error: 0.8879 - mean_squared_error: 0.78
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3256 - accuracy: 0.9000 - mean_absolute_error: 0.8694 - root_mean_squared_error: 1.1201 - mean_squared_error: 1.2546 - val_loss: 0.4032 - val_accuracy: 0.7667 - val_mean_absolute_error: 0.9667 - val_root_mean_squared_error: 1.2000 - val_mean_squared_error: 1.4401
# Epoch 25/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.4361 - accuracy: 0.8750 - mean_absolute_error: 0.7083 - root_mean_squared_error: 1.0052 - mean_squared_error: 1.01
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1652 - accuracy: 0.9417 - mean_absolute_error: 0.8694 - root_mean_squared_error: 1.1221 - mean_squared_error: 1.2590 - val_loss: 0.2122 - val_accuracy: 0.9333 - val_mean_absolute_error: 0.9667 - val_root_mean_squared_error: 1.2113 - val_mean_squared_error: 1.4673

# %%
time_took_to_run = sum(cb.logs)
time_took_to_run
# Out:
# 5.062231291551143

# %%
# Predict using the trained model
train_predictions = model.predict(x_train)
test_predictions = model.predict(x_test)
# Out:
# 4/4 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 10ms/step

# %%
index = []
for array in test_predictions:
    for i in range(len(array)):
        if max(array, key=lambda x: x) == array[i]:
            index.append(i)

# Evaluate the model on training and testing data
test_rmse = np.sqrt(metrics.mean_squared_error(y_test, index))
print("Accuracy (validation): " + str(metrics.accuracy_score(y_test, index)))
print(f"F1 Score: {metrics.f1_score(y_test, index , average='micro')}")
print(f"Log Loss: {metrics.log_loss(y_test, test_predictions)}")
print(f"Confusion Matrix: {metrics.multilabel_confusion_matrix(y_test, index)}")
# Out:
# Accuracy (validation): 0.9333333333333333
# F1 Score: 0.9333333333333333
# Log Loss: 0.21222032261365553
# Confusion Matrix: [[[19  2]
#   [ 0  9]]
#
#  [[21  0]
#   [ 2  7]]
#
#  [[18  0]
#   [ 0 12]]]

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(f1, label="F1")
plt.title('F1 Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('F1')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(log_loss, label="Log Loss")
plt.title('Log Loss Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Log Loss')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(accuracy, label="Accuracy")
plt.title('Accuracy Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# %%
cm = metrics.confusion_matrix(y_test, index)
print(cm)
sns.heatmap(cm, cmap="Blues", cbar=False, annot=True, fmt='d', xticklabels=["Setosa", "Versicolor", "Virginica"], yticklabels=["Setosa", "Versicolor", "Virginica"])
# Out:
# [[ 9  0  0]
#  [ 2  7  0]
#  [ 0  0 12]]
# <Axes: >
