# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
import tensorflow as tf
from timeit import default_timer as timer
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
# Load the dataset
shampoo_data = pd.read_csv("../shampoo_sales.csv")

# Display the first few rows of the dataset
print(shampoo_data.head())
# Out:
#   Month  Sales
# 0  1-01  266.0
# 1  1-02  145.9
# 2  1-03  183.1
# 3  1-04  119.3
# 4  1-05  180.3

# %%
shampoo_series = shampoo_data['Sales'].values.astype(float)


# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
shampoo_series_scaled = scaler.fit_transform(shampoo_series.reshape(-1, 1))

# %%
# Plot the time series data
plt.figure(figsize=(10, 6))
plt.plot(shampoo_series, label='Shampoo Sales')
plt.title('Shampoo Sales Time Series')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.legend()
plt.show()

# %%
# Function to create the dataset with input features and labels
def create_dataset(series, look_back=1):
    X, y = [], []
    for i in range(len(series) - look_back):
        X.append(series[i:(i + look_back), 0])
        y.append(series[i + look_back, 0])
    return np.array(X), np.array(y)

# %%
look_back = 7  # You can experiment with different values
X, y = create_dataset(shampoo_series_scaled, look_back)

# Reshape input to be [samples, time steps, features]
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

# Split the data into training and testing sets
train_size = int(len(X) * 0.8)
test_size = len(X) - train_size
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
mse = []
mae = []  
rmse = []
r2 = []
class PredictionCallback(tf.keras.callbacks.Callback):    
  def on_epoch_end(self, epoch, logs={}):
    y_pred = self.model.predict(X_test)
    index = []

    # Evaluate the model on training and testing data
    test_rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
    rmse.append(test_rmse)
    mse.append(metrics.mean_squared_error(y_test, y_pred))
    mae.append((metrics.mean_absolute_error(y_test, y_pred)))
    r2.append(metrics.r2_score(y_test, y_pred))

# %%
class Model_Timer(tf.keras.callbacks.Callback):
    def __init__(self):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

# %%
model = Sequential([
    LSTM(units=50, return_sequences=True, input_shape=(X.shape[1], 1)),
    LSTM(units=50, return_sequences=True),
    LSTM(units=50, return_sequences=True),
    LSTM(units=50),
    Dense(units=1)
])
cb = Model_Timer()
# Compile the model
model.compile(optimizer=tf.optimizers.legacy.Adam(learning_rate=0.001), loss="mse", metrics=["MeanAbsoluteError","RootMeanSquaredError", "MeanSquaredError"])
model.fit(X_train, y_train, batch_size=8, epochs=25, validation_data=(X_test, y_test),callbacks=[PredictionCallback(), cb])
# Out:
# Epoch 1/25
# 1/1 [==============================] - 1s 598ms/steps: 0.1749 - mean_absolute_error: 0.3743 - root_mean_squared_error: 0.4182 - mean_squared_error: 0.17
# 3/3 [==============================] - 3s 586ms/step - loss: 0.1097 - mean_absolute_error: 0.2825 - root_mean_squared_error: 0.3312 - mean_squared_error: 0.1097 - val_loss: 0.5535 - val_mean_absolute_error: 0.7250 - val_root_mean_squared_error: 0.7440 - val_mean_squared_error: 0.5535
# Epoch 2/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0856 - mean_absolute_error: 0.2577 - root_mean_squared_error: 0.2925 - mean_squared_error: 0.08
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0781 - mean_absolute_error: 0.2289 - root_mean_squared_error: 0.2794 - mean_squared_error: 0.0781 - val_loss: 0.4299 - val_mean_absolute_error: 0.6344 - val_root_mean_squared_error: 0.6557 - val_mean_squared_error: 0.4299
# Epoch 3/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0802 - mean_absolute_error: 0.2428 - root_mean_squared_error: 0.2832 - mean_squared_error: 0.08
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0496 - mean_absolute_error: 0.1780 - root_mean_squared_error: 0.2226 - mean_squared_error: 0.0496 - val_loss: 0.2708 - val_mean_absolute_error: 0.4941 - val_root_mean_squared_error: 0.5204 - val_mean_squared_error: 0.2708
# Epoch 4/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0081 - mean_absolute_error: 0.0814 - root_mean_squared_error: 0.0902 - mean_squared_error: 0.00
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0224 - mean_absolute_error: 0.1230 - root_mean_squared_error: 0.1498 - mean_squared_error: 0.0224 - val_loss: 0.1240 - val_mean_absolute_error: 0.3138 - val_root_mean_squared_error: 0.3522 - val_mean_squared_error: 0.1240
# Epoch 5/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0312 - mean_absolute_error: 0.1475 - root_mean_squared_error: 0.1766 - mean_squared_error: 0.03
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0322 - mean_absolute_error: 0.1533 - root_mean_squared_error: 0.1795 - mean_squared_error: 0.0322 - val_loss: 0.1007 - val_mean_absolute_error: 0.2747 - val_root_mean_squared_error: 0.3173 - val_mean_squared_error: 0.1007
# Epoch 6/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0302 - mean_absolute_error: 0.1511 - root_mean_squared_error: 0.1737 - mean_squared_error: 0.03
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0309 - mean_absolute_error: 0.1514 - root_mean_squared_error: 0.1759 - mean_squared_error: 0.0309 - val_loss: 0.1617 - val_mean_absolute_error: 0.3687 - val_root_mean_squared_error: 0.4021 - val_mean_squared_error: 0.1617
# Epoch 7/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0178 - mean_absolute_error: 0.1034 - root_mean_squared_error: 0.1333 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0255 - mean_absolute_error: 0.1357 - root_mean_squared_error: 0.1598 - mean_squared_error: 0.0255 - val_loss: 0.2179 - val_mean_absolute_error: 0.4379 - val_root_mean_squared_error: 0.4668 - val_mean_squared_error: 0.2179
# Epoch 8/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0245 - mean_absolute_error: 0.1325 - root_mean_squared_error: 0.1566 - mean_squared_error: 0.02
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0245 - mean_absolute_error: 0.1319 - root_mean_squared_error: 0.1564 - mean_squared_error: 0.0245 - val_loss: 0.2323 - val_mean_absolute_error: 0.4541 - val_root_mean_squared_error: 0.4820 - val_mean_squared_error: 0.2323
# Epoch 9/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0344 - mean_absolute_error: 0.1612 - root_mean_squared_error: 0.1856 - mean_squared_error: 0.03
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0243 - mean_absolute_error: 0.1311 - root_mean_squared_error: 0.1558 - mean_squared_error: 0.0243 - val_loss: 0.2127 - val_mean_absolute_error: 0.4323 - val_root_mean_squared_error: 0.4612 - val_mean_squared_error: 0.2127
# Epoch 10/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0198 - mean_absolute_error: 0.1284 - root_mean_squared_error: 0.1407 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0228 - mean_absolute_error: 0.1280 - root_mean_squared_error: 0.1511 - mean_squared_error: 0.0228 - val_loss: 0.1739 - val_mean_absolute_error: 0.3855 - val_root_mean_squared_error: 0.4170 - val_mean_squared_error: 0.1739
# Epoch 11/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0204 - mean_absolute_error: 0.1103 - root_mean_squared_error: 0.1429 - mean_squared_error: 0.02
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0205 - mean_absolute_error: 0.1199 - root_mean_squared_error: 0.1433 - mean_squared_error: 0.0205 - val_loss: 0.1388 - val_mean_absolute_error: 0.3378 - val_root_mean_squared_error: 0.3726 - val_mean_squared_error: 0.1388
# Epoch 12/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0250 - mean_absolute_error: 0.1262 - root_mean_squared_error: 0.1582 - mean_squared_error: 0.02
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0202 - mean_absolute_error: 0.1207 - root_mean_squared_error: 0.1420 - mean_squared_error: 0.0202 - val_loss: 0.1102 - val_mean_absolute_error: 0.2934 - val_root_mean_squared_error: 0.3319 - val_mean_squared_error: 0.1102
# Epoch 13/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0237 - mean_absolute_error: 0.1293 - root_mean_squared_error: 0.1538 - mean_squared_error: 0.02
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0201 - mean_absolute_error: 0.1199 - root_mean_squared_error: 0.1418 - mean_squared_error: 0.0201 - val_loss: 0.1057 - val_mean_absolute_error: 0.2862 - val_root_mean_squared_error: 0.3251 - val_mean_squared_error: 0.1057
# Epoch 14/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0157 - mean_absolute_error: 0.0989 - root_mean_squared_error: 0.1253 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0183 - mean_absolute_error: 0.1139 - root_mean_squared_error: 0.1351 - mean_squared_error: 0.0183 - val_loss: 0.0956 - val_mean_absolute_error: 0.2687 - val_root_mean_squared_error: 0.3092 - val_mean_squared_error: 0.0956
# Epoch 15/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0094 - mean_absolute_error: 0.0865 - root_mean_squared_error: 0.0967 - mean_squared_error: 0.00
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0171 - mean_absolute_error: 0.1108 - root_mean_squared_error: 0.1307 - mean_squared_error: 0.0171 - val_loss: 0.0882 - val_mean_absolute_error: 0.2554 - val_root_mean_squared_error: 0.2970 - val_mean_squared_error: 0.0882
# Epoch 16/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0125 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1119 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0162 - mean_absolute_error: 0.1081 - root_mean_squared_error: 0.1272 - mean_squared_error: 0.0162 - val_loss: 0.0746 - val_mean_absolute_error: 0.2282 - val_root_mean_squared_error: 0.2731 - val_mean_squared_error: 0.0746
# Epoch 17/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0124 - mean_absolute_error: 0.0975 - root_mean_squared_error: 0.1113 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0148 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1216 - mean_squared_error: 0.0148 - val_loss: 0.0470 - val_mean_absolute_error: 0.1755 - val_root_mean_squared_error: 0.2167 - val_mean_squared_error: 0.0470
# Epoch 18/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0150 - mean_absolute_error: 0.1071 - root_mean_squared_error: 0.1225 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0143 - mean_absolute_error: 0.1008 - root_mean_squared_error: 0.1195 - mean_squared_error: 0.0143 - val_loss: 0.0287 - val_mean_absolute_error: 0.1353 - val_root_mean_squared_error: 0.1694 - val_mean_squared_error: 0.0287
# Epoch 19/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0190 - mean_absolute_error: 0.1200 - root_mean_squared_error: 0.1379 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0132 - mean_absolute_error: 0.0956 - root_mean_squared_error: 0.1150 - mean_squared_error: 0.0132 - val_loss: 0.0235 - val_mean_absolute_error: 0.1286 - val_root_mean_squared_error: 0.1533 - val_mean_squared_error: 0.0235
# Epoch 20/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0121 - mean_absolute_error: 0.0824 - root_mean_squared_error: 0.1098 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0131 - mean_absolute_error: 0.0939 - root_mean_squared_error: 0.1143 - mean_squared_error: 0.0131 - val_loss: 0.0245 - val_mean_absolute_error: 0.1285 - val_root_mean_squared_error: 0.1566 - val_mean_squared_error: 0.0245
# Epoch 21/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0118 - mean_absolute_error: 0.0804 - root_mean_squared_error: 0.1087 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0128 - mean_absolute_error: 0.0889 - root_mean_squared_error: 0.1131 - mean_squared_error: 0.0128 - val_loss: 0.0280 - val_mean_absolute_error: 0.1286 - val_root_mean_squared_error: 0.1674 - val_mean_squared_error: 0.0280
# Epoch 22/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0119 - mean_absolute_error: 0.0800 - root_mean_squared_error: 0.1090 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0135 - mean_absolute_error: 0.0922 - root_mean_squared_error: 0.1163 - mean_squared_error: 0.0135 - val_loss: 0.0251 - val_mean_absolute_error: 0.1285 - val_root_mean_squared_error: 0.1584 - val_mean_squared_error: 0.0251
# Epoch 23/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0107 - mean_absolute_error: 0.0923 - root_mean_squared_error: 0.1035 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0125 - mean_absolute_error: 0.0880 - root_mean_squared_error: 0.1116 - mean_squared_error: 0.0125 - val_loss: 0.0257 - val_mean_absolute_error: 0.1545 - val_root_mean_squared_error: 0.1602 - val_mean_squared_error: 0.0257
# Epoch 24/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0070 - mean_absolute_error: 0.0694 - root_mean_squared_error: 0.0839 - mean_squared_error: 0.00
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0128 - mean_absolute_error: 0.0893 - root_mean_squared_error: 0.1133 - mean_squared_error: 0.0128 - val_loss: 0.0294 - val_mean_absolute_error: 0.1667 - val_root_mean_squared_error: 0.1715 - val_mean_squared_error: 0.0294
# Epoch 25/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0210 - mean_absolute_error: 0.1286 - root_mean_squared_error: 0.1447 - mean_squared_error: 0.02
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0139 - mean_absolute_error: 0.0942 - root_mean_squared_error: 0.1179 - mean_squared_error: 0.0139 - val_loss: 0.0236 - val_mean_absolute_error: 0.1322 - val_root_mean_squared_error: 0.1538 - val_mean_squared_error: 0.0236

# %%
time_took_to_run = sum(cb.logs)
print(time_took_to_run)
# Out:
# 4.429650253150612

# %%
# Predict using the trained model
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step

# %%
# Evaluate the model on training and testing data
train_rmse = np.sqrt(mean_squared_error(y_train, train_predictions))
test_rmse = np.sqrt(mean_squared_error(y_test, test_predictions))
print(f'Training RMSE: {train_rmse}')
print(f"Testing RMSE: {test_rmse}")
print("MSE (validation): " + str(mean_squared_error(y_test, test_predictions)))
print("MAE (validation): " + str(mean_absolute_error(y_test, test_predictions)))
print(f"R2 Validation: {metrics.r2_score(y_test, test_predictions)}" )
# Out:
# Training RMSE: 0.11191969299827005
# Testing RMSE: 0.15377076976457993
# MSE (validation): 0.023645449633991452
# MAE (validation): 0.132195116837198
# R2 Validation: 0.16061674296630468

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(mse, label="Mean Squared Error")
plt.title('MSE Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(mae, label="Mean Absolute Error")
plt.title('MAE Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(rmse, label="Root Mean Squared Error")
plt.title('RMSE Per Epoch')
plt.xlabel('Epoch')
plt.xlim(1,25)
plt.ylabel('RMSE')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(r2, label="R2 Score")
plt.title('R2 Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('R2')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(scaler.inverse_transform(test_predictions.reshape(-1,1)), label="Predictions")
plt.plot(scaler.inverse_transform(y_test.reshape(-1,1)), label="Actual")
plt.title('Predictions vs. Actual')
plt.xlabel("Month")
plt.ylabel("Sales")
plt.legend()
