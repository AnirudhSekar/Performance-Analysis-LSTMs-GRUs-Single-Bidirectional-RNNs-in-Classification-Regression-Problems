# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN
import tensorflow as tf
import os
import seaborn as sns

from sklearn.model_selection import train_test_split
from timeit import default_timer as timer

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
df = pd.read_csv("../Iris.csv")
df.replace(to_replace="Iris-setosa", value=0, inplace=True)
df.replace("Iris-versicolor", 1, inplace=True)
df.replace("Iris-virginica", 2, inplace=True)
df.head()
# Out:
# /var/folders/8_/t3znlm6s3n1gdhfwvmxv3gp40000gn/T/ipykernel_38286/1182936694.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace("Iris-virginica", 2, inplace=True)
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
X = df[df.columns[:len(df.columns)-1]]
y = df["Species"]

scaler = MinMaxScaler(feature_range=(0,1))
X = scaler.fit_transform(np.array(X))
X = np.reshape(X, (X.shape[0], X.shape[1], 1))
x_train, x_test, y_train, y_test = train_test_split(X, y, train_size=0.8)

# %%
f1 = []
log_loss = []  
accuracy = []
class PredictionCallback(tf.keras.callbacks.Callback):    
  def on_epoch_end(self, epoch, logs={}):
    y_pred = self.model.predict(x_test)
    index = []
    for array in y_pred:
        for i in range(len(array)):
            if max(array, key=lambda x: x) == array[i]:
                index.append(i)

    # Evaluate the model on training and testing data
    f1.append(metrics.f1_score(y_test, index , average='micro'))
    log_loss.append((metrics.log_loss(y_test, y_pred)))
    accuracy.append(metrics.balanced_accuracy_score(y_test, index))

# %%
class Model_Timer(tf.keras.callbacks.Callback):
    def __init__(self):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

# %%
model = Sequential([
    (SimpleRNN(50,return_sequences=True)),
    (SimpleRNN(50,return_sequences=True)),
    (SimpleRNN(50,return_sequences=True)),
    (SimpleRNN(50)),
    Dense(3, activation="softmax")
])
cb = Model_Timer()
# Compile the model
model.compile(optimizer=tf.optimizers.legacy.Adam(learning_rate=0.001), loss="sparse_categorical_crossentropy", metrics=["accuracy", "MeanAbsoluteError","RootMeanSquaredError", "MeanSquaredError"])
model.fit(x_train, y_train, batch_size=8, epochs=25, validation_data=(x_test, y_test),callbacks=[PredictionCallback(), cb])
# Out:
# Epoch 1/25
# 1/1 [==============================] - 0s 165ms/steploss: 1.6925 - accuracy: 0.1250 - mean_absolute_error: 1.2500 - root_mean_squared_error: 1.3889 - mean_squared_error: 1.92
# 15/15 [==============================] - 1s 35ms/step - loss: 0.9203 - accuracy: 0.4333 - mean_absolute_error: 0.9083 - root_mean_squared_error: 1.0895 - mean_squared_error: 1.1870 - val_loss: 0.5518 - val_accuracy: 0.7667 - val_mean_absolute_error: 0.8111 - val_root_mean_squared_error: 1.0065 - val_mean_squared_error: 1.0130
# Epoch 2/25
# 1/1 [==============================] - 0s 10ms/steploss: 0.5139 - accuracy: 0.8750 - mean_absolute_error: 1.0833 - root_mean_squared_error: 1.2596 - mean_squared_error: 1.58
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4563 - accuracy: 0.8667 - mean_absolute_error: 0.9083 - root_mean_squared_error: 1.1107 - mean_squared_error: 1.2336 - val_loss: 0.3605 - val_accuracy: 0.8333 - val_mean_absolute_error: 0.8111 - val_root_mean_squared_error: 1.0248 - val_mean_squared_error: 1.0503
# Epoch 3/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.4503 - accuracy: 0.7500 - mean_absolute_error: 0.9167 - root_mean_squared_error: 1.1327 - mean_squared_error: 1.28
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3475 - accuracy: 0.8917 - mean_absolute_error: 0.9083 - root_mean_squared_error: 1.1224 - mean_squared_error: 1.2597 - val_loss: 0.2649 - val_accuracy: 0.9333 - val_mean_absolute_error: 0.8111 - val_root_mean_squared_error: 1.0346 - val_mean_squared_error: 1.0704
# Epoch 4/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.2523 - accuracy: 0.8750 - mean_absolute_error: 0.9167 - root_mean_squared_error: 1.1514 - mean_squared_error: 1.32
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2720 - accuracy: 0.9000 - mean_absolute_error: 0.9083 - root_mean_squared_error: 1.1319 - mean_squared_error: 1.2813 - val_loss: 0.1866 - val_accuracy: 1.0000 - val_mean_absolute_error: 0.8111 - val_root_mean_squared_error: 1.0425 - val_mean_squared_error: 1.0867
# Epoch 5/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.2933 - accuracy: 1.0000 - mean_absolute_error: 1.0000 - root_mean_squared_error: 1.1782 - mean_squared_error: 1.38
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2186 - accuracy: 0.9417 - mean_absolute_error: 0.9083 - root_mean_squared_error: 1.1398 - mean_squared_error: 1.2992 - val_loss: 0.2380 - val_accuracy: 0.9000 - val_mean_absolute_error: 0.8111 - val_root_mean_squared_error: 1.0490 - val_mean_squared_error: 1.1004
# Epoch 6/25
# 1/1 [==============================] - 0s 10ms/steploss: 0.2026 - accuracy: 0.8750 - mean_absolute_error: 0.8750 - root_mean_squared_error: 1.1456 - mean_squared_error: 1.31
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2000 - accuracy: 0.9167 - mean_absolute_error: 0.9083 - root_mean_squared_error: 1.1436 - mean_squared_error: 1.3079 - val_loss: 0.0997 - val_accuracy: 1.0000 - val_mean_absolute_error: 0.8111 - val_root_mean_squared_error: 1.0565 - val_mean_squared_error: 1.1163
# Epoch 7/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.1795 - accuracy: 1.0000 - mean_absolute_error: 1.0417 - root_mean_squared_error: 1.2075 - mean_squared_error: 1.45
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1319 - accuracy: 0.9833 - mean_absolute_error: 0.9083 - root_mean_squared_error: 1.1491 - mean_squared_error: 1.3205 - val_loss: 0.1333 - val_accuracy: 0.9333 - val_mean_absolute_error: 0.8111 - val_root_mean_squared_error: 1.0599 - val_mean_squared_error: 1.1233
# Epoch 8/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0328 - accuracy: 1.0000 - mean_absolute_error: 1.0000 - root_mean_squared_error: 1.2832 - mean_squared_error: 1.64
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1432 - accuracy: 0.9333 - mean_absolute_error: 0.9083 - root_mean_squared_error: 1.1537 - mean_squared_error: 1.3310 - val_loss: 0.0927 - val_accuracy: 0.9667 - val_mean_absolute_error: 0.8111 - val_root_mean_squared_error: 1.0630 - val_mean_squared_error: 1.1301
# Epoch 9/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0655 - accuracy: 1.0000 - mean_absolute_error: 1.2500 - root_mean_squared_error: 1.4304 - mean_squared_error: 2.04
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1874 - accuracy: 0.9167 - mean_absolute_error: 0.9083 - root_mean_squared_error: 1.1536 - mean_squared_error: 1.3308 - val_loss: 0.0646 - val_accuracy: 1.0000 - val_mean_absolute_error: 0.8111 - val_root_mean_squared_error: 1.0659 - val_mean_squared_error: 1.1362
# Epoch 10/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0596 - accuracy: 1.0000 - mean_absolute_error: 0.7500 - root_mean_squared_error: 1.0245 - mean_squared_error: 1.04
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0916 - accuracy: 0.9667 - mean_absolute_error: 0.9083 - root_mean_squared_error: 1.1582 - mean_squared_error: 1.3415 - val_loss: 0.1049 - val_accuracy: 0.9667 - val_mean_absolute_error: 0.8111 - val_root_mean_squared_error: 1.0651 - val_mean_squared_error: 1.1344
# Epoch 11/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.3720 - accuracy: 0.7500 - mean_absolute_error: 0.9583 - root_mean_squared_error: 1.1827 - mean_squared_error: 1.39
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1312 - accuracy: 0.9500 - mean_absolute_error: 0.9083 - root_mean_squared_error: 1.1587 - mean_squared_error: 1.3427 - val_loss: 0.0550 - val_accuracy: 1.0000 - val_mean_absolute_error: 0.8111 - val_root_mean_squared_error: 1.0681 - val_mean_squared_error: 1.1408
# Epoch 12/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0804 - accuracy: 1.0000 - mean_absolute_error: 0.5833 - root_mean_squared_error: 0.8481 - mean_squared_error: 0.71
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1091 - accuracy: 0.9833 - mean_absolute_error: 0.9083 - root_mean_squared_error: 1.1594 - mean_squared_error: 1.3443 - val_loss: 0.0634 - val_accuracy: 0.9667 - val_mean_absolute_error: 0.8111 - val_root_mean_squared_error: 1.0698 - val_mean_squared_error: 1.1446
# Epoch 13/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0886 - accuracy: 1.0000 - mean_absolute_error: 0.9583 - root_mean_squared_error: 1.1956 - mean_squared_error: 1.42
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0709 - accuracy: 0.9667 - mean_absolute_error: 0.9083 - root_mean_squared_error: 1.1611 - mean_squared_error: 1.3481 - val_loss: 0.0436 - val_accuracy: 1.0000 - val_mean_absolute_error: 0.8111 - val_root_mean_squared_error: 1.0706 - val_mean_squared_error: 1.1462
# Epoch 14/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0487 - accuracy: 1.0000 - mean_absolute_error: 1.2083 - root_mean_squared_error: 1.4204 - mean_squared_error: 2.01
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0717 - accuracy: 0.9750 - mean_absolute_error: 0.9083 - root_mean_squared_error: 1.1616 - mean_squared_error: 1.3493 - val_loss: 0.0207 - val_accuracy: 1.0000 - val_mean_absolute_error: 0.8111 - val_root_mean_squared_error: 1.0742 - val_mean_squared_error: 1.1538
# Epoch 15/25
# 1/1 [==============================] - 0s 10ms/steploss: 0.0191 - accuracy: 1.0000 - mean_absolute_error: 0.7917 - root_mean_squared_error: 1.0550 - mean_squared_error: 1.11
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0833 - accuracy: 0.9667 - mean_absolute_error: 0.9083 - root_mean_squared_error: 1.1642 - mean_squared_error: 1.3555 - val_loss: 0.0244 - val_accuracy: 1.0000 - val_mean_absolute_error: 0.8111 - val_root_mean_squared_error: 1.0735 - val_mean_squared_error: 1.1525
# Epoch 16/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0277 - accuracy: 1.0000 - mean_absolute_error: 1.2083 - root_mean_squared_error: 1.4232 - mean_squared_error: 2.02
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1028 - accuracy: 0.9500 - mean_absolute_error: 0.9083 - root_mean_squared_error: 1.1618 - mean_squared_error: 1.3499 - val_loss: 0.0212 - val_accuracy: 1.0000 - val_mean_absolute_error: 0.8111 - val_root_mean_squared_error: 1.0742 - val_mean_squared_error: 1.1538
# Epoch 17/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0309 - accuracy: 1.0000 - mean_absolute_error: 0.9583 - root_mean_squared_error: 1.1998 - mean_squared_error: 1.43
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0684 - accuracy: 0.9833 - mean_absolute_error: 0.9083 - root_mean_squared_error: 1.1634 - mean_squared_error: 1.3536 - val_loss: 0.0165 - val_accuracy: 1.0000 - val_mean_absolute_error: 0.8111 - val_root_mean_squared_error: 1.0753 - val_mean_squared_error: 1.1563
# Epoch 18/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0145 - accuracy: 1.0000 - mean_absolute_error: 1.0833 - root_mean_squared_error: 1.3194 - mean_squared_error: 1.74
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1194 - accuracy: 0.9500 - mean_absolute_error: 0.9083 - root_mean_squared_error: 1.1640 - mean_squared_error: 1.3549 - val_loss: 0.0265 - val_accuracy: 1.0000 - val_mean_absolute_error: 0.8111 - val_root_mean_squared_error: 1.0739 - val_mean_squared_error: 1.1533
# Epoch 19/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0403 - accuracy: 1.0000 - mean_absolute_error: 0.6250 - root_mean_squared_error: 0.8784 - mean_squared_error: 0.77
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1101 - accuracy: 0.9500 - mean_absolute_error: 0.9083 - root_mean_squared_error: 1.1635 - mean_squared_error: 1.3536 - val_loss: 0.1020 - val_accuracy: 0.9667 - val_mean_absolute_error: 0.8111 - val_root_mean_squared_error: 1.0717 - val_mean_squared_error: 1.1484
# Epoch 20/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.1663 - accuracy: 0.8750 - mean_absolute_error: 0.9583 - root_mean_squared_error: 1.1958 - mean_squared_error: 1.42
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1213 - accuracy: 0.9500 - mean_absolute_error: 0.9083 - root_mean_squared_error: 1.1611 - mean_squared_error: 1.3483 - val_loss: 0.0768 - val_accuracy: 0.9667 - val_mean_absolute_error: 0.8111 - val_root_mean_squared_error: 1.0700 - val_mean_squared_error: 1.1449
# Epoch 21/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0965 - accuracy: 1.0000 - mean_absolute_error: 1.1250 - root_mean_squared_error: 1.3243 - mean_squared_error: 1.75
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0919 - accuracy: 0.9750 - mean_absolute_error: 0.9083 - root_mean_squared_error: 1.1636 - mean_squared_error: 1.3539 - val_loss: 0.0850 - val_accuracy: 0.9333 - val_mean_absolute_error: 0.8111 - val_root_mean_squared_error: 1.0691 - val_mean_squared_error: 1.1431
# Epoch 22/25
# 1/1 [==============================] - 0s 8ms/step loss: 0.0882 - accuracy: 1.0000 - mean_absolute_error: 0.9583 - root_mean_squared_error: 1.1966 - mean_squared_error: 1.43
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0791 - accuracy: 0.9750 - mean_absolute_error: 0.9083 - root_mean_squared_error: 1.1643 - mean_squared_error: 1.3555 - val_loss: 0.0184 - val_accuracy: 1.0000 - val_mean_absolute_error: 0.8111 - val_root_mean_squared_error: 1.0750 - val_mean_squared_error: 1.1556
# Epoch 23/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0242 - accuracy: 1.0000 - mean_absolute_error: 0.8333 - root_mean_squared_error: 1.0733 - mean_squared_error: 1.15
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0358 - accuracy: 0.9917 - mean_absolute_error: 0.9083 - root_mean_squared_error: 1.1660 - mean_squared_error: 1.3595 - val_loss: 0.0173 - val_accuracy: 1.0000 - val_mean_absolute_error: 0.8111 - val_root_mean_squared_error: 1.0755 - val_mean_squared_error: 1.1566
# Epoch 24/25
# 1/1 [==============================] - 0s 10ms/steploss: 0.0081 - accuracy: 1.0000 - mean_absolute_error: 0.4167 - root_mean_squared_error: 0.6414 - mean_squared_error: 0.41
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0474 - accuracy: 0.9833 - mean_absolute_error: 0.9083 - root_mean_squared_error: 1.1658 - mean_squared_error: 1.3590 - val_loss: 0.0112 - val_accuracy: 1.0000 - val_mean_absolute_error: 0.8111 - val_root_mean_squared_error: 1.0768 - val_mean_squared_error: 1.1595
# Epoch 25/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0224 - accuracy: 1.0000 - mean_absolute_error: 0.8333 - root_mean_squared_error: 1.0737 - mean_squared_error: 1.15
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0307 - accuracy: 0.9917 - mean_absolute_error: 0.9083 - root_mean_squared_error: 1.1680 - mean_squared_error: 1.3643 - val_loss: 0.0197 - val_accuracy: 1.0000 - val_mean_absolute_error: 0.8111 - val_root_mean_squared_error: 1.0751 - val_mean_squared_error: 1.1557

# %%
time_took_to_run = sum(cb.logs)
time_took_to_run
# Out:
# 2.8415416702628136

# %%
# Predict using the trained model
train_predictions = model.predict(x_train)
test_predictions = model.predict(x_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 9ms/step

# %%
index = []
for array in test_predictions:
    for i in range(len(array)):
        if max(array, key=lambda x: x) == array[i]:
            index.append(i)

# Evaluate the model on training and testing data
test_rmse = np.sqrt(metrics.mean_squared_error(y_test, index))
print("Accuracy (balanced): " + str(metrics.accuracy_score(y_test, index)))
print(f"F1 Score: {metrics.f1_score(y_test, index , average='micro')}")
print(f"Log Loss: {metrics.log_loss(y_test, test_predictions)}")
print(f"Confusion Matrix: {metrics.multilabel_confusion_matrix(y_test, index)}")
print(max(accuracy)-min(accuracy))
# Out:
# Accuracy (balanced): 1.0
# F1 Score: 1.0
# Log Loss: 0.01974530315794838
# Confusion Matrix: [[[19  0]
#   [ 0 11]]
#
#  [[19  0]
#   [ 0 11]]
#
#  [[22  0]
#   [ 0  8]]]
# 0.21212121212121204

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(f1, label="F1")
plt.title('F1 Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('F1')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(log_loss, label="Log Loss")
plt.title('Log Loss Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Log Loss')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(accuracy, label="Accuracy")
plt.title('Accuracy Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# %%
cm = metrics.confusion_matrix(y_test, index)
print(cm)
sns.heatmap(cm, cmap="Blues", cbar=False, annot=True, fmt='d', xticklabels=["Setosa", "Versicolor", "Virginica"], yticklabels=["Setosa", "Versicolor", "Virginica"])
# Out:
# [[11  0  0]
#  [ 0 11  0]
#  [ 0  0  8]]
# <Axes: >
