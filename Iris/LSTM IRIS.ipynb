# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
import tensorflow as tf
import os
import seaborn as sns
from sklearn.model_selection import train_test_split
from timeit import default_timer as timer

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
df = pd.read_csv("../Iris.csv")
df.replace(to_replace="Iris-setosa", value=0, inplace=True)
df.replace("Iris-versicolor", 1, inplace=True)
df.replace("Iris-virginica", 2, inplace=True)
df.head()
# Out:
# /var/folders/8_/t3znlm6s3n1gdhfwvmxv3gp40000gn/T/ipykernel_91871/1182936694.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace("Iris-virginica", 2, inplace=True)
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
X = df[df.columns[:len(df.columns)-1]]
y = df["Species"]

scaler = MinMaxScaler(feature_range=(0,1))
X = scaler.fit_transform(np.array(X))
X = np.reshape(X, (X.shape[0], X.shape[1], 1))
x_train, x_test, y_train, y_test = train_test_split(X, y, train_size=0.8)

# %%
f1 = []
log_loss = []  
accuracy = []
class PredictionCallback(tf.keras.callbacks.Callback):    
  def on_epoch_end(self, epoch, logs={}):
    y_pred = self.model.predict(x_test)
    index = []
    for array in y_pred:
        for i in range(len(array)):
            if max(array, key=lambda x: x) == array[i]:
                index.append(i)

    # Evaluate the model on training and testing data
    f1.append(metrics.f1_score(y_test, index , average='micro'))
    log_loss.append((metrics.log_loss(y_test, y_pred)))
    accuracy.append(metrics.balanced_accuracy_score(y_test, index))

# %%
class Model_Timer(tf.keras.callbacks.Callback):
    def __init__(self):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

# %%
model = Sequential([
    LSTM(50,return_sequences=True),
    LSTM(50,return_sequences=True),
    LSTM(50,return_sequences=True),
    LSTM(50),
    Dense(3, activation="softmax")
])
cb = Model_Timer()
# Compile the model
model.compile(optimizer=tf.optimizers.legacy.Adam(learning_rate=0.001), loss="sparse_categorical_crossentropy", metrics=["accuracy", "MeanAbsoluteError","RootMeanSquaredError", "MeanSquaredError"])
model.fit(x_train, y_train, batch_size=8, epochs=25, validation_data=(x_test, y_test),callbacks=[PredictionCallback(), cb])
# Out:
# Epoch 1/25
# 1/1 [==============================] - 1s 515ms/steploss: 1.0977 - accuracy: 0.3750 - mean_absolute_error: 1.1250 - root_mean_squared_error: 1.2528 - mean_squared_error: 1.56
# 15/15 [==============================] - 4s 106ms/step - loss: 1.0967 - accuracy: 0.2833 - mean_absolute_error: 0.8917 - root_mean_squared_error: 1.0554 - mean_squared_error: 1.1140 - val_loss: 1.0918 - val_accuracy: 0.3000 - val_mean_absolute_error: 0.8778 - val_root_mean_squared_error: 1.0489 - val_mean_squared_error: 1.1001
# Epoch 2/25
# 1/1 [==============================] - 0s 9ms/step loss: 1.0762 - accuracy: 0.3750 - mean_absolute_error: 1.2917 - root_mean_squared_error: 1.3795 - mean_squared_error: 1.90
# 15/15 [==============================] - 0s 5ms/step - loss: 1.0725 - accuracy: 0.3417 - mean_absolute_error: 0.8917 - root_mean_squared_error: 1.0558 - mean_squared_error: 1.1147 - val_loss: 1.0397 - val_accuracy: 0.3333 - val_mean_absolute_error: 0.8778 - val_root_mean_squared_error: 1.0506 - val_mean_squared_error: 1.1038
# Epoch 3/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.9804 - accuracy: 0.3472 - mean_absolute_error: 0.9259 - root_mean_squared_error: 1.0863 - mean_squared_error: 1.18
# 15/15 [==============================] - 0s 8ms/step - loss: 0.9625 - accuracy: 0.3750 - mean_absolute_error: 0.8917 - root_mean_squared_error: 1.0645 - mean_squared_error: 1.1331 - val_loss: 0.8493 - val_accuracy: 0.5000 - val_mean_absolute_error: 0.8778 - val_root_mean_squared_error: 1.0643 - val_mean_squared_error: 1.1327
# Epoch 4/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.7041 - accuracy: 0.7500 - mean_absolute_error: 1.0000 - root_mean_squared_error: 1.2195 - mean_squared_error: 1.48
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6820 - accuracy: 0.6750 - mean_absolute_error: 0.8917 - root_mean_squared_error: 1.0796 - mean_squared_error: 1.1656 - val_loss: 0.5416 - val_accuracy: 0.7333 - val_mean_absolute_error: 0.8778 - val_root_mean_squared_error: 1.0992 - val_mean_squared_error: 1.2083
# Epoch 5/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.2844 - accuracy: 1.0000 - mean_absolute_error: 1.2083 - root_mean_squared_error: 1.3939 - mean_squared_error: 1.94
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4779 - accuracy: 0.7833 - mean_absolute_error: 0.8917 - root_mean_squared_error: 1.1085 - mean_squared_error: 1.2289 - val_loss: 0.5250 - val_accuracy: 0.8000 - val_mean_absolute_error: 0.8778 - val_root_mean_squared_error: 1.1158 - val_mean_squared_error: 1.2450
# Epoch 6/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.6924 - accuracy: 0.6250 - mean_absolute_error: 1.1667 - root_mean_squared_error: 1.3265 - mean_squared_error: 1.75
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3575 - accuracy: 0.8667 - mean_absolute_error: 0.8917 - root_mean_squared_error: 1.1152 - mean_squared_error: 1.2436 - val_loss: 0.3264 - val_accuracy: 0.9000 - val_mean_absolute_error: 0.8778 - val_root_mean_squared_error: 1.1144 - val_mean_squared_error: 1.2420
# Epoch 7/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.2259 - accuracy: 0.9250 - mean_absolute_error: 0.8417 - root_mean_squared_error: 1.0810 - mean_squared_error: 1.16
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2118 - accuracy: 0.9250 - mean_absolute_error: 0.8917 - root_mean_squared_error: 1.1265 - mean_squared_error: 1.2690 - val_loss: 0.2229 - val_accuracy: 0.8667 - val_mean_absolute_error: 0.8778 - val_root_mean_squared_error: 1.1278 - val_mean_squared_error: 1.2720
# Epoch 8/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.1367 - accuracy: 1.0000 - mean_absolute_error: 0.7500 - root_mean_squared_error: 1.0092 - mean_squared_error: 1.01
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1533 - accuracy: 0.9500 - mean_absolute_error: 0.8917 - root_mean_squared_error: 1.1391 - mean_squared_error: 1.2976 - val_loss: 0.0800 - val_accuracy: 1.0000 - val_mean_absolute_error: 0.8778 - val_root_mean_squared_error: 1.1341 - val_mean_squared_error: 1.2863
# Epoch 9/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0190 - accuracy: 1.0000 - mean_absolute_error: 1.1667 - root_mean_squared_error: 1.3496 - mean_squared_error: 1.82
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2280 - accuracy: 0.9083 - mean_absolute_error: 0.8917 - root_mean_squared_error: 1.1419 - mean_squared_error: 1.3038 - val_loss: 0.0793 - val_accuracy: 0.9667 - val_mean_absolute_error: 0.8778 - val_root_mean_squared_error: 1.1353 - val_mean_squared_error: 1.2889
# Epoch 10/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.6261 - accuracy: 0.7500 - mean_absolute_error: 0.6667 - root_mean_squared_error: 0.8922 - mean_squared_error: 0.79
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1768 - accuracy: 0.9417 - mean_absolute_error: 0.8917 - root_mean_squared_error: 1.1419 - mean_squared_error: 1.3039 - val_loss: 0.1671 - val_accuracy: 0.9000 - val_mean_absolute_error: 0.8778 - val_root_mean_squared_error: 1.1349 - val_mean_squared_error: 1.2880
# Epoch 11/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.2113 - accuracy: 0.9107 - mean_absolute_error: 0.9137 - root_mean_squared_error: 1.1577 - mean_squared_error: 1.34
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2012 - accuracy: 0.9167 - mean_absolute_error: 0.8917 - root_mean_squared_error: 1.1396 - mean_squared_error: 1.2986 - val_loss: 0.1037 - val_accuracy: 0.9667 - val_mean_absolute_error: 0.8778 - val_root_mean_squared_error: 1.1335 - val_mean_squared_error: 1.2848
# Epoch 12/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.1340 - accuracy: 0.8750 - mean_absolute_error: 0.7500 - root_mean_squared_error: 1.0198 - mean_squared_error: 1.04
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1325 - accuracy: 0.9500 - mean_absolute_error: 0.8917 - root_mean_squared_error: 1.1407 - mean_squared_error: 1.3013 - val_loss: 0.0743 - val_accuracy: 1.0000 - val_mean_absolute_error: 0.8778 - val_root_mean_squared_error: 1.1344 - val_mean_squared_error: 1.2868
# Epoch 13/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.1228 - accuracy: 0.8750 - mean_absolute_error: 1.0417 - root_mean_squared_error: 1.2936 - mean_squared_error: 1.67
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1417 - accuracy: 0.9417 - mean_absolute_error: 0.8917 - root_mean_squared_error: 1.1419 - mean_squared_error: 1.3040 - val_loss: 0.0737 - val_accuracy: 1.0000 - val_mean_absolute_error: 0.8778 - val_root_mean_squared_error: 1.1351 - val_mean_squared_error: 1.2884
# Epoch 14/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0285 - accuracy: 1.0000 - mean_absolute_error: 0.5833 - root_mean_squared_error: 0.8560 - mean_squared_error: 0.73
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1273 - accuracy: 0.9583 - mean_absolute_error: 0.8917 - root_mean_squared_error: 1.1428 - mean_squared_error: 1.3060 - val_loss: 0.0612 - val_accuracy: 1.0000 - val_mean_absolute_error: 0.8778 - val_root_mean_squared_error: 1.1372 - val_mean_squared_error: 1.2933
# Epoch 15/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.1163 - accuracy: 0.9519 - mean_absolute_error: 0.8654 - root_mean_squared_error: 1.1176 - mean_squared_error: 1.24
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1171 - accuracy: 0.9583 - mean_absolute_error: 0.8917 - root_mean_squared_error: 1.1437 - mean_squared_error: 1.3080 - val_loss: 0.2010 - val_accuracy: 0.8667 - val_mean_absolute_error: 0.8778 - val_root_mean_squared_error: 1.1368 - val_mean_squared_error: 1.2923
# Epoch 16/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0654 - accuracy: 1.0000 - mean_absolute_error: 0.7083 - root_mean_squared_error: 1.0036 - mean_squared_error: 1.00
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1308 - accuracy: 0.9583 - mean_absolute_error: 0.8917 - root_mean_squared_error: 1.1462 - mean_squared_error: 1.3138 - val_loss: 0.1939 - val_accuracy: 0.8667 - val_mean_absolute_error: 0.8778 - val_root_mean_squared_error: 1.1373 - val_mean_squared_error: 1.2935
# Epoch 17/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.1221 - accuracy: 1.0000 - mean_absolute_error: 0.9583 - root_mean_squared_error: 1.1914 - mean_squared_error: 1.41
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1316 - accuracy: 0.9417 - mean_absolute_error: 0.8917 - root_mean_squared_error: 1.1455 - mean_squared_error: 1.3121 - val_loss: 0.1353 - val_accuracy: 0.9333 - val_mean_absolute_error: 0.8778 - val_root_mean_squared_error: 1.1379 - val_mean_squared_error: 1.2949
# Epoch 18/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.1090 - accuracy: 1.0000 - mean_absolute_error: 1.0833 - root_mean_squared_error: 1.3083 - mean_squared_error: 1.71
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1926 - accuracy: 0.9083 - mean_absolute_error: 0.8917 - root_mean_squared_error: 1.1436 - mean_squared_error: 1.3079 - val_loss: 0.1777 - val_accuracy: 0.9000 - val_mean_absolute_error: 0.8778 - val_root_mean_squared_error: 1.1377 - val_mean_squared_error: 1.2943
# Epoch 19/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.1724 - accuracy: 0.9318 - mean_absolute_error: 0.8750 - root_mean_squared_error: 1.1201 - mean_squared_error: 1.25
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1848 - accuracy: 0.9250 - mean_absolute_error: 0.8917 - root_mean_squared_error: 1.1435 - mean_squared_error: 1.3076 - val_loss: 0.0500 - val_accuracy: 1.0000 - val_mean_absolute_error: 0.8778 - val_root_mean_squared_error: 1.1394 - val_mean_squared_error: 1.2982
# Epoch 20/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0220 - accuracy: 1.0000 - mean_absolute_error: 1.0833 - root_mean_squared_error: 1.3177 - mean_squared_error: 1.73
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1269 - accuracy: 0.9583 - mean_absolute_error: 0.8917 - root_mean_squared_error: 1.1431 - mean_squared_error: 1.3066 - val_loss: 0.1120 - val_accuracy: 0.9667 - val_mean_absolute_error: 0.8778 - val_root_mean_squared_error: 1.1349 - val_mean_squared_error: 1.2880
# Epoch 21/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0302 - accuracy: 1.0000 - mean_absolute_error: 0.7917 - root_mean_squared_error: 1.0521 - mean_squared_error: 1.10
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1127 - accuracy: 0.9667 - mean_absolute_error: 0.8917 - root_mean_squared_error: 1.1457 - mean_squared_error: 1.3127 - val_loss: 0.2025 - val_accuracy: 0.9000 - val_mean_absolute_error: 0.8778 - val_root_mean_squared_error: 1.1394 - val_mean_squared_error: 1.2982
# Epoch 22/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0063 - accuracy: 1.0000 - mean_absolute_error: 1.2083 - root_mean_squared_error: 1.4274 - mean_squared_error: 2.03
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1270 - accuracy: 0.9583 - mean_absolute_error: 0.8917 - root_mean_squared_error: 1.1416 - mean_squared_error: 1.3033 - val_loss: 0.1540 - val_accuracy: 0.9333 - val_mean_absolute_error: 0.8778 - val_root_mean_squared_error: 1.1404 - val_mean_squared_error: 1.3005
# Epoch 23/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0915 - accuracy: 0.9659 - mean_absolute_error: 0.8826 - root_mean_squared_error: 1.1385 - mean_squared_error: 1.29
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1077 - accuracy: 0.9500 - mean_absolute_error: 0.8917 - root_mean_squared_error: 1.1450 - mean_squared_error: 1.3110 - val_loss: 0.4009 - val_accuracy: 0.8667 - val_mean_absolute_error: 0.8778 - val_root_mean_squared_error: 1.1408 - val_mean_squared_error: 1.3015
# Epoch 24/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0062 - accuracy: 1.0000 - mean_absolute_error: 1.0833 - root_mean_squared_error: 1.3213 - mean_squared_error: 1.74
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1640 - accuracy: 0.9167 - mean_absolute_error: 0.8917 - root_mean_squared_error: 1.1447 - mean_squared_error: 1.3104 - val_loss: 0.0614 - val_accuracy: 1.0000 - val_mean_absolute_error: 0.8778 - val_root_mean_squared_error: 1.1378 - val_mean_squared_error: 1.2947
# Epoch 25/25
# 1/1 [==============================] - 0s 9ms/step loss: 0.0091 - accuracy: 1.0000 - mean_absolute_error: 1.0833 - root_mean_squared_error: 1.3206 - mean_squared_error: 1.74
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1195 - accuracy: 0.9667 - mean_absolute_error: 0.8917 - root_mean_squared_error: 1.1468 - mean_squared_error: 1.3152 - val_loss: 0.0800 - val_accuracy: 0.9667 - val_mean_absolute_error: 0.8778 - val_root_mean_squared_error: 1.1400 - val_mean_squared_error: 1.2996

# %%
time_took_to_run = sum(cb.logs)
time_took_to_run
# Out:
# 5.543126581935212

# %%
# Predict using the trained model
train_predictions = model.predict(x_train)
test_predictions = model.predict(x_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 10ms/step

# %%
index = []
for array in test_predictions:
    for i in range(len(array)):
        if max(array, key=lambda x: x) == array[i]:
            index.append(i)

# Evaluate the model on training and testing data
test_rmse = np.sqrt(metrics.mean_squared_error(y_test, index))
print("Accuracy (validation): " + str(metrics.accuracy_score(y_test, index)))
print(f"F1 Score: {metrics.f1_score(y_test, index , average='micro')}")
print(f"Log Loss: {metrics.log_loss(y_test, test_predictions)}")
print(f"Confusion Matrix: {metrics.multilabel_confusion_matrix(y_test, index)}")
# Out:
# Accuracy (validation): 0.9666666666666667
# F1 Score: 0.9666666666666667
# Log Loss: 0.07997073092240403
# Confusion Matrix: [[[19  0]
#   [ 0 11]]
#
#  [[21  0]
#   [ 1  8]]
#
#  [[19  1]
#   [ 0 10]]]

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(f1, label="F1")
plt.title('F1 Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('F1')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(log_loss, label="Log Loss")
plt.title('Log Loss Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Log Loss')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(accuracy, label="Accuracy")
plt.title('Accuracy Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.figure(figsize=(14,6))
#       2 plt.subplot(1, 2, 1)
#       3 plt.plot(accuracy, label="Accuracy")
#
# NameError: name 'plt' is not defined

# %%
cm = metrics.confusion_matrix(y_test, index)
print(cm)
sns.heatmap(cm, cmap="Blues", cbar=False, annot=True, fmt='d', xticklabels=["Setosa", "Versicolor", "Virginica"], yticklabels=["Setosa", "Versicolor", "Virginica"])
# Out:
# [[11  0  0]
#  [ 0  8  1]
#  [ 0  0 10]]
# <Axes: >
