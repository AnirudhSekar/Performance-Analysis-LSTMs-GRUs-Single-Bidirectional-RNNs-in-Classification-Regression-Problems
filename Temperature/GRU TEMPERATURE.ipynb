# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU
import tensorflow as tf
import os
from timeit import default_timer as timer

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
# Load the dataset
weather_data = pd.read_csv("../austin_weather.csv")

# Display the first few rows of the dataset
print(weather_data.head())
# Out:
#          Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0  2013-12-21         74        60        45            67           49
# 1  2013-12-22         56        48        39            43           36
# 2  2013-12-23         58        45        32            31           27
# 3  2013-12-24         61        46        31            36           28
# 4  2013-12-25         58        50        41            44           40
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  ...  \
# 0           43                  93                 75                 57  ...
# 1           28                  93                 68                 43  ...
# 2           23                  76                 52                 27  ...
# 3           21                  89                 56                 22  ...
# 4           36                  86                 71                 56  ...
#
#   SeaLevelPressureAvgInches SeaLevelPressureLowInches VisibilityHighMiles  \
# 0                     29.68                     29.59                  10
# 1                     30.13                     29.87                  10
# 2                     30.49                     30.41                  10
# 3                     30.45                      30.3                  10
# 4                     30.33                     30.27                  10
#
#   VisibilityAvgMiles VisibilityLowMiles WindHighMPH WindAvgMPH WindGustMPH  \
# 0                  7                  2          20          4          31
# 1                 10                  5          16          6          25
# 2                 10                 10           8          3          12
# 3                 10                  7          12          4          20
# 4                 10                  7          10          2          16
#
#   PrecipitationSumInches               Events
# 0                   0.46  Rain , Thunderstorm
# 1                      0
# 2                      0
# 3                      0
# 4                      T
#
# [5 rows x 21 columns]

# %%
# Extract the 'TempAvgF' column as a time series
temperature_series = weather_data['TempAvgF'].values.astype(float)


# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
temperature_series_scaled = scaler.fit_transform(temperature_series.reshape(-1, 1))

# %%
# Plot the time series data
plt.figure(figsize=(10, 6))
plt.plot(temperature_series, label='Austin Temperature')
plt.title('Austin Temperature Time Series')
plt.xlabel('Month')
plt.ylabel('Avg Temperature')
plt.legend()
plt.show()

# %%
# Function to create the dataset with input features and labels
def create_dataset(series, look_back=1):
    X, y = [], []
    for i in range(len(series) - look_back):
        X.append(series[i:(i + look_back), 0])
        y.append(series[i + look_back, 0])
    return np.array(X), np.array(y)

# %%
look_back = 7  # You can experiment with different values
X, y = create_dataset(temperature_series_scaled, look_back)

# Reshape input to be [samples, time steps, features]
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

# Split the data into training and testing sets
train_size = int(len(X) * 0.8)
test_size = len(X) - train_size
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
mse = []
mae = []  
rmse = []
r2 = []
class PredictionCallback(tf.keras.callbacks.Callback):    
  def on_epoch_end(self, epoch, logs={}):
    y_pred = self.model.predict(X_test)
    index = []

    # Evaluate the model on training and testing data
    test_rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
    rmse.append(test_rmse)
    mse.append(metrics.mean_squared_error(y_test, y_pred))
    mae.append((metrics.mean_absolute_error(y_test, y_pred)))
    r2.append(metrics.r2_score(y_test, y_pred))

# %%
class Model_Timer(tf.keras.callbacks.Callback):
    def __init__(self):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

# %%
model = Sequential([
    GRU(units=50, return_sequences=True, input_shape=(X.shape[1], 1)),
    GRU(units=50, return_sequences=True),
    GRU(units=50, return_sequences=True),
    GRU(units=50),
    Dense(units=1)
])

cb = Model_Timer()
# Compile the model
model.compile(optimizer=tf.optimizers.legacy.Adam(learning_rate=0.001), loss="mse", metrics=["MeanAbsoluteError","RootMeanSquaredError", "MeanSquaredError"])
model.fit(X_train, y_train, batch_size=8, epochs=25, validation_data=(X_test, y_test),callbacks=[PredictionCallback(), cb])
# Out:
# Epoch 1/25
# 9/9 [==============================] - 1s 1ms/step - loss: 0.0284 - mean_absolute_error: 0.1177 - root_mean_squared_error: 0.1684 - mean_squared_error: 0.02
# 132/132 [==============================] - 4s 14ms/step - loss: 0.0284 - mean_absolute_error: 0.1177 - root_mean_squared_error: 0.1684 - mean_squared_error: 0.0284 - val_loss: 0.0174 - val_mean_absolute_error: 0.0945 - val_root_mean_squared_error: 0.1317 - val_mean_squared_error: 0.0174
# Epoch 2/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0130 - mean_absolute_error: 0.0870 - root_mean_squared_error: 0.1140 - mean_squared_error: 0.01
# 132/132 [==============================] - 1s 6ms/step - loss: 0.0130 - mean_absolute_error: 0.0870 - root_mean_squared_error: 0.1139 - mean_squared_error: 0.0130 - val_loss: 0.0167 - val_mean_absolute_error: 0.1015 - val_root_mean_squared_error: 0.1293 - val_mean_squared_error: 0.0167
# Epoch 3/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0119 - mean_absolute_error: 0.0825 - root_mean_squared_error: 0.1090 - mean_squared_error: 0.01
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0119 - mean_absolute_error: 0.0826 - root_mean_squared_error: 0.1091 - mean_squared_error: 0.0119 - val_loss: 0.0151 - val_mean_absolute_error: 0.0937 - val_root_mean_squared_error: 0.1231 - val_mean_squared_error: 0.0151
# Epoch 4/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0119 - mean_absolute_error: 0.0836 - root_mean_squared_error: 0.1093 - mean_squared_error: 0.01
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0119 - mean_absolute_error: 0.0835 - root_mean_squared_error: 0.1090 - mean_squared_error: 0.0119 - val_loss: 0.0142 - val_mean_absolute_error: 0.0904 - val_root_mean_squared_error: 0.1190 - val_mean_squared_error: 0.0142
# Epoch 5/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0107 - mean_absolute_error: 0.0781 - root_mean_squared_error: 0.1032 - mean_squared_error: 0.01
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0107 - mean_absolute_error: 0.0780 - root_mean_squared_error: 0.1032 - mean_squared_error: 0.0107 - val_loss: 0.0113 - val_mean_absolute_error: 0.0805 - val_root_mean_squared_error: 0.1064 - val_mean_squared_error: 0.0113
# Epoch 6/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0078 - mean_absolute_error: 0.0662 - root_mean_squared_error: 0.0885 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 6ms/step - loss: 0.0078 - mean_absolute_error: 0.0661 - root_mean_squared_error: 0.0885 - mean_squared_error: 0.0078 - val_loss: 0.0085 - val_mean_absolute_error: 0.0660 - val_root_mean_squared_error: 0.0922 - val_mean_squared_error: 0.0085
# Epoch 7/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0072 - mean_absolute_error: 0.0626 - root_mean_squared_error: 0.0847 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0072 - mean_absolute_error: 0.0627 - root_mean_squared_error: 0.0847 - mean_squared_error: 0.0072 - val_loss: 0.0091 - val_mean_absolute_error: 0.0760 - val_root_mean_squared_error: 0.0956 - val_mean_squared_error: 0.0091
# Epoch 8/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0071 - mean_absolute_error: 0.0632 - root_mean_squared_error: 0.0841 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0071 - mean_absolute_error: 0.0634 - root_mean_squared_error: 0.0845 - mean_squared_error: 0.0071 - val_loss: 0.0090 - val_mean_absolute_error: 0.0753 - val_root_mean_squared_error: 0.0949 - val_mean_squared_error: 0.0090
# Epoch 9/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0069 - mean_absolute_error: 0.0632 - root_mean_squared_error: 0.0830 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0069 - mean_absolute_error: 0.0629 - root_mean_squared_error: 0.0828 - mean_squared_error: 0.0069 - val_loss: 0.0097 - val_mean_absolute_error: 0.0788 - val_root_mean_squared_error: 0.0986 - val_mean_squared_error: 0.0097
# Epoch 10/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0069 - mean_absolute_error: 0.0625 - root_mean_squared_error: 0.0831 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0069 - mean_absolute_error: 0.0624 - root_mean_squared_error: 0.0831 - mean_squared_error: 0.0069 - val_loss: 0.0081 - val_mean_absolute_error: 0.0651 - val_root_mean_squared_error: 0.0901 - val_mean_squared_error: 0.0081
# Epoch 11/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0067 - mean_absolute_error: 0.0611 - root_mean_squared_error: 0.0817 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0067 - mean_absolute_error: 0.0610 - root_mean_squared_error: 0.0816 - mean_squared_error: 0.0067 - val_loss: 0.0083 - val_mean_absolute_error: 0.0676 - val_root_mean_squared_error: 0.0908 - val_mean_squared_error: 0.0083
# Epoch 12/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0067 - mean_absolute_error: 0.0610 - root_mean_squared_error: 0.0820 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 6ms/step - loss: 0.0067 - mean_absolute_error: 0.0609 - root_mean_squared_error: 0.0818 - mean_squared_error: 0.0067 - val_loss: 0.0080 - val_mean_absolute_error: 0.0648 - val_root_mean_squared_error: 0.0894 - val_mean_squared_error: 0.0080
# Epoch 13/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0065 - mean_absolute_error: 0.0607 - root_mean_squared_error: 0.0809 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0067 - mean_absolute_error: 0.0613 - root_mean_squared_error: 0.0815 - mean_squared_error: 0.0067 - val_loss: 0.0081 - val_mean_absolute_error: 0.0640 - val_root_mean_squared_error: 0.0901 - val_mean_squared_error: 0.0081
# Epoch 14/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0071 - mean_absolute_error: 0.0633 - root_mean_squared_error: 0.0840 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0069 - mean_absolute_error: 0.0629 - root_mean_squared_error: 0.0833 - mean_squared_error: 0.0069 - val_loss: 0.0081 - val_mean_absolute_error: 0.0643 - val_root_mean_squared_error: 0.0901 - val_mean_squared_error: 0.0081
# Epoch 15/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0067 - mean_absolute_error: 0.0609 - root_mean_squared_error: 0.0821 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0066 - mean_absolute_error: 0.0605 - root_mean_squared_error: 0.0815 - mean_squared_error: 0.0066 - val_loss: 0.0103 - val_mean_absolute_error: 0.0769 - val_root_mean_squared_error: 0.1017 - val_mean_squared_error: 0.0103
# Epoch 16/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0076 - mean_absolute_error: 0.0655 - root_mean_squared_error: 0.0869 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0074 - mean_absolute_error: 0.0649 - root_mean_squared_error: 0.0861 - mean_squared_error: 0.0074 - val_loss: 0.0086 - val_mean_absolute_error: 0.0659 - val_root_mean_squared_error: 0.0929 - val_mean_squared_error: 0.0086
# Epoch 17/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0066 - mean_absolute_error: 0.0608 - root_mean_squared_error: 0.0814 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0066 - mean_absolute_error: 0.0602 - root_mean_squared_error: 0.0810 - mean_squared_error: 0.0066 - val_loss: 0.0081 - val_mean_absolute_error: 0.0654 - val_root_mean_squared_error: 0.0898 - val_mean_squared_error: 0.0081
# Epoch 18/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0065 - mean_absolute_error: 0.0600 - root_mean_squared_error: 0.0808 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 6ms/step - loss: 0.0065 - mean_absolute_error: 0.0601 - root_mean_squared_error: 0.0808 - mean_squared_error: 0.0065 - val_loss: 0.0095 - val_mean_absolute_error: 0.0725 - val_root_mean_squared_error: 0.0972 - val_mean_squared_error: 0.0095
# Epoch 19/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0064 - mean_absolute_error: 0.0589 - root_mean_squared_error: 0.0797 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0065 - mean_absolute_error: 0.0596 - root_mean_squared_error: 0.0806 - mean_squared_error: 0.0065 - val_loss: 0.0081 - val_mean_absolute_error: 0.0657 - val_root_mean_squared_error: 0.0902 - val_mean_squared_error: 0.0081
# Epoch 20/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0066 - mean_absolute_error: 0.0610 - root_mean_squared_error: 0.0813 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0066 - mean_absolute_error: 0.0610 - root_mean_squared_error: 0.0812 - mean_squared_error: 0.0066 - val_loss: 0.0084 - val_mean_absolute_error: 0.0701 - val_root_mean_squared_error: 0.0914 - val_mean_squared_error: 0.0084
# Epoch 21/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0066 - mean_absolute_error: 0.0607 - root_mean_squared_error: 0.0812 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 6ms/step - loss: 0.0066 - mean_absolute_error: 0.0608 - root_mean_squared_error: 0.0811 - mean_squared_error: 0.0066 - val_loss: 0.0086 - val_mean_absolute_error: 0.0696 - val_root_mean_squared_error: 0.0928 - val_mean_squared_error: 0.0086
# Epoch 22/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0064 - mean_absolute_error: 0.0586 - root_mean_squared_error: 0.0800 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0063 - mean_absolute_error: 0.0585 - root_mean_squared_error: 0.0797 - mean_squared_error: 0.0063 - val_loss: 0.0083 - val_mean_absolute_error: 0.0646 - val_root_mean_squared_error: 0.0911 - val_mean_squared_error: 0.0083
# Epoch 23/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0066 - mean_absolute_error: 0.0602 - root_mean_squared_error: 0.0811 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0064 - mean_absolute_error: 0.0594 - root_mean_squared_error: 0.0802 - mean_squared_error: 0.0064 - val_loss: 0.0099 - val_mean_absolute_error: 0.0809 - val_root_mean_squared_error: 0.0993 - val_mean_squared_error: 0.0099
# Epoch 24/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0069 - mean_absolute_error: 0.0622 - root_mean_squared_error: 0.0829 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0068 - mean_absolute_error: 0.0621 - root_mean_squared_error: 0.0827 - mean_squared_error: 0.0068 - val_loss: 0.0089 - val_mean_absolute_error: 0.0662 - val_root_mean_squared_error: 0.0943 - val_mean_squared_error: 0.0089
# Epoch 25/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0067 - mean_absolute_error: 0.0608 - root_mean_squared_error: 0.0816 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0067 - mean_absolute_error: 0.0609 - root_mean_squared_error: 0.0817 - mean_squared_error: 0.0067 - val_loss: 0.0082 - val_mean_absolute_error: 0.0646 - val_root_mean_squared_error: 0.0905 - val_mean_squared_error: 0.0082

# %%
time_took_to_run = sum(cb.logs)
print(time_took_to_run)
# Out:
# 21.10600954340771

# %%
# Predict using the trained model
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)
# Out:
#  1/33 [..............................] - ETA: 0s
# 33/33 [==============================] - 0s 1ms/step
# 9/9 [==============================] - 0s 1ms/step

# %%
# Evaluate the model on training and testing data
train_rmse = np.sqrt(mean_squared_error(y_train, train_predictions))
test_rmse = np.sqrt(mean_squared_error(y_test, test_predictions))
print(f'Training RMSE: {train_rmse}')
print(f"Testing RMSE: {test_rmse}")
print("MSE (validation): " + str(mean_squared_error(y_test, test_predictions)))
print("MAE (validation): " + str(mean_absolute_error(y_test, test_predictions)))
print(f"R2 Validation: {metrics.r2_score(y_test, test_predictions)}" )
# Out:
# Training RMSE: 0.07724957130517958
# Testing RMSE: 0.0905442842001393
# MSE (validation): 0.008198267401315596
# MAE (validation): 0.06462920799908076
# R2 Validation: 0.8072642431995694

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(mse, label="Mean Squared Error")
plt.title('MSE Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(mae, label="Mean Absolute Error")
plt.title('MAE Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(rmse, label="Root Mean Squared Error")
plt.title('RMSE Per Epoch')
plt.xlabel('Epoch')
plt.xlim(1,25)
plt.ylabel('RMSE')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(r2, label="R2 Score")
plt.title('R2 Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('R2')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(scaler.inverse_transform(test_predictions.reshape(-1,1)), label="Predictions")
plt.plot(scaler.inverse_transform(y_test.reshape(-1,1)), label="Actual")
plt.title('Predictions vs. Actual')
plt.xlabel("Month")
plt.ylabel("Avg Temperature")
plt.legend()
