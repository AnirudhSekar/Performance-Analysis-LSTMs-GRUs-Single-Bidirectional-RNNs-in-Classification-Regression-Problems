# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_squared_error
from sklearn import metrics
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
import tensorflow as tf
import os
from timeit import default_timer as timer

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
# Load the dataset
weather_data = pd.read_csv("../austin_weather.csv")

# Display the first few rows of the dataset
print(weather_data.head())
# Out:
#          Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0  2013-12-21         74        60        45            67           49
# 1  2013-12-22         56        48        39            43           36
# 2  2013-12-23         58        45        32            31           27
# 3  2013-12-24         61        46        31            36           28
# 4  2013-12-25         58        50        41            44           40
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  ...  \
# 0           43                  93                 75                 57  ...
# 1           28                  93                 68                 43  ...
# 2           23                  76                 52                 27  ...
# 3           21                  89                 56                 22  ...
# 4           36                  86                 71                 56  ...
#
#   SeaLevelPressureAvgInches SeaLevelPressureLowInches VisibilityHighMiles  \
# 0                     29.68                     29.59                  10
# 1                     30.13                     29.87                  10
# 2                     30.49                     30.41                  10
# 3                     30.45                      30.3                  10
# 4                     30.33                     30.27                  10
#
#   VisibilityAvgMiles VisibilityLowMiles WindHighMPH WindAvgMPH WindGustMPH  \
# 0                  7                  2          20          4          31
# 1                 10                  5          16          6          25
# 2                 10                 10           8          3          12
# 3                 10                  7          12          4          20
# 4                 10                  7          10          2          16
#
#   PrecipitationSumInches               Events
# 0                   0.46  Rain , Thunderstorm
# 1                      0
# 2                      0
# 3                      0
# 4                      T
#
# [5 rows x 21 columns]

# %%
# Extract the 'TempAvgF' column as a time series
temperature_series = weather_data['TempAvgF'].values.astype(float)

print(len(temperature_series))
# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
temperature_series_scaled = scaler.fit_transform(temperature_series.reshape(-1, 1))
# Out:
# 1319

# %%
# Plot the time series data
plt.figure(figsize=(10, 6))
plt.plot(temperature_series, label='Austin Temperature')
plt.title('Austin Temperature Time Series')
plt.xlabel('Month')
plt.ylabel('Avg Temperature')
plt.legend()
plt.show()

# %%
# Function to create the dataset with input features and labels
def create_dataset(series, look_back=1):
    X, y = [], []
    for i in range(len(series) - look_back):
        X.append(series[i:(i + look_back), 0])
        y.append(series[i + look_back, 0])
    return np.array(X), np.array(y)

# %%
look_back = 7  # You can experiment with different values
X, y = create_dataset(temperature_series_scaled, look_back)

# Reshape input to be [samples, time steps, features]
X = np.reshape(X, (X.shape[0], X.shape[1], 1))


# Split the data into training and testing sets
train_size = int(len(X) * 0.8)
test_size = len(X) - train_size
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

print(X_train)
# Out:
# [[[0.484375]
#   [0.296875]
#   [0.25    ]
#   ...
#   [0.328125]
#   [0.296875]
#   [0.375   ]]
#
#  [[0.296875]
#   [0.25    ]
#   [0.265625]
#   ...
#   [0.296875]
#   [0.375   ]
#   [0.34375 ]]
#
#  [[0.25    ]
#   [0.265625]
#   [0.328125]
#   ...
#   [0.375   ]
#   [0.34375 ]
#   [0.328125]]
#
#  ...
#
#  [[0.8125  ]
#   [0.8125  ]
#   [0.703125]
#   ...
#   [0.609375]
#   [0.609375]
#   [0.578125]]
#
#  [[0.8125  ]
#   [0.703125]
#   [0.65625 ]
#   ...
#   [0.609375]
#   [0.578125]
#   [0.578125]]
#
#  [[0.703125]
#   [0.65625 ]
#   [0.609375]
#   ...
#   [0.578125]
#   [0.578125]
#   [0.53125 ]]]

# %%
mse = []
mae = []  
rmse = []
r2 = []
class PredictionCallback(tf.keras.callbacks.Callback):    
  def on_epoch_end(self, epoch, logs={}):
    y_pred = self.model.predict(X_test)
    

    # Evaluate the model on training and testing data
    test_rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
    rmse.append(test_rmse)
    mse.append(metrics.mean_squared_error(y_test, y_pred))
    mae.append((metrics.mean_absolute_error(y_test, y_pred)))
    r2.append(metrics.r2_score(y_test, y_pred))

# %%
class Model_Timer(tf.keras.callbacks.Callback):
    def __init__(self):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

# %%
model = Sequential([
    (SimpleRNN(units=50, return_sequences=True, input_shape=(X.shape[1], 1))),
    (SimpleRNN(units=50, return_sequences=True)),
    (SimpleRNN(units=50, return_sequences=True)),
    (SimpleRNN(units=50)),
    Dense(units=1)
])

cb = Model_Timer()
# Compile the model
model.compile(optimizer=tf.optimizers.legacy.Adam(learning_rate=0.001), loss="mse", metrics=["MeanAbsoluteError","RootMeanSquaredError", "MeanSquaredError"])
model.fit(X_train, y_train, batch_size=8, epochs=25, validation_data=(X_test, y_test),callbacks=[PredictionCallback(), cb])
# Out:
# Epoch 1/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0290 - mean_absolute_error: 0.1258 - root_mean_squared_error: 0.1703 - mean_squared_error: 0.02
# 132/132 [==============================] - 2s 5ms/step - loss: 0.0282 - mean_absolute_error: 0.1238 - root_mean_squared_error: 0.1679 - mean_squared_error: 0.0282 - val_loss: 0.0223 - val_mean_absolute_error: 0.1275 - val_root_mean_squared_error: 0.1493 - val_mean_squared_error: 0.0223
# Epoch 2/25
# 9/9 [==============================] - 0s 940us/step loss: 0.0123 - mean_absolute_error: 0.0869 - root_mean_squared_error: 0.1111 - mean_squared_error: 0.01
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0125 - mean_absolute_error: 0.0870 - root_mean_squared_error: 0.1119 - mean_squared_error: 0.0125 - val_loss: 0.0194 - val_mean_absolute_error: 0.1182 - val_root_mean_squared_error: 0.1394 - val_mean_squared_error: 0.0194
# Epoch 3/25
# 9/9 [==============================] - 0s 837us/step loss: 0.0133 - mean_absolute_error: 0.0878 - root_mean_squared_error: 0.1154 - mean_squared_error: 0.01
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0129 - mean_absolute_error: 0.0871 - root_mean_squared_error: 0.1136 - mean_squared_error: 0.0129 - val_loss: 0.0161 - val_mean_absolute_error: 0.1039 - val_root_mean_squared_error: 0.1270 - val_mean_squared_error: 0.0161
# Epoch 4/25
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0096 - mean_absolute_error: 0.0753 - root_mean_squared_error: 0.0980 - mean_squared_error: 0.00
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0095 - mean_absolute_error: 0.0746 - root_mean_squared_error: 0.0973 - mean_squared_error: 0.0095 - val_loss: 0.0102 - val_mean_absolute_error: 0.0708 - val_root_mean_squared_error: 0.1012 - val_mean_squared_error: 0.0102
# Epoch 5/25
# 9/9 [==============================] - 0s 858us/step loss: 0.0096 - mean_absolute_error: 0.0749 - root_mean_squared_error: 0.0978 - mean_squared_error: 0.00
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0096 - mean_absolute_error: 0.0752 - root_mean_squared_error: 0.0979 - mean_squared_error: 0.0096 - val_loss: 0.0091 - val_mean_absolute_error: 0.0679 - val_root_mean_squared_error: 0.0954 - val_mean_squared_error: 0.0091
# Epoch 6/25
# 9/9 [==============================] - 0s 842us/step loss: 0.0093 - mean_absolute_error: 0.0746 - root_mean_squared_error: 0.0964 - mean_squared_error: 0.00
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0091 - mean_absolute_error: 0.0734 - root_mean_squared_error: 0.0951 - mean_squared_error: 0.0091 - val_loss: 0.0085 - val_mean_absolute_error: 0.0695 - val_root_mean_squared_error: 0.0921 - val_mean_squared_error: 0.0085
# Epoch 7/25
# 9/9 [==============================] - 0s 864us/step loss: 0.0076 - mean_absolute_error: 0.0667 - root_mean_squared_error: 0.0873 - mean_squared_error: 0.00
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0078 - mean_absolute_error: 0.0673 - root_mean_squared_error: 0.0883 - mean_squared_error: 0.0078 - val_loss: 0.0113 - val_mean_absolute_error: 0.0889 - val_root_mean_squared_error: 0.1064 - val_mean_squared_error: 0.0113
# Epoch 8/25
# 9/9 [==============================] - 0s 844us/step loss: 0.0087 - mean_absolute_error: 0.0714 - root_mean_squared_error: 0.0931 - mean_squared_error: 0.00
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0084 - mean_absolute_error: 0.0703 - root_mean_squared_error: 0.0916 - mean_squared_error: 0.0084 - val_loss: 0.0093 - val_mean_absolute_error: 0.0676 - val_root_mean_squared_error: 0.0966 - val_mean_squared_error: 0.0093
# Epoch 9/25
# 9/9 [==============================] - 0s 848us/step loss: 0.0080 - mean_absolute_error: 0.0674 - root_mean_squared_error: 0.0894 - mean_squared_error: 0.00
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0082 - mean_absolute_error: 0.0688 - root_mean_squared_error: 0.0905 - mean_squared_error: 0.0082 - val_loss: 0.0109 - val_mean_absolute_error: 0.0835 - val_root_mean_squared_error: 0.1046 - val_mean_squared_error: 0.0109
# Epoch 10/25
# 9/9 [==============================] - 0s 902us/step loss: 0.0082 - mean_absolute_error: 0.0702 - root_mean_squared_error: 0.0905 - mean_squared_error: 0.00
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0080 - mean_absolute_error: 0.0694 - root_mean_squared_error: 0.0895 - mean_squared_error: 0.0080 - val_loss: 0.0092 - val_mean_absolute_error: 0.0673 - val_root_mean_squared_error: 0.0961 - val_mean_squared_error: 0.0092
# Epoch 11/25
# 9/9 [==============================] - 0s 895us/step loss: 0.0072 - mean_absolute_error: 0.0649 - root_mean_squared_error: 0.0847 - mean_squared_error: 0.00
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0075 - mean_absolute_error: 0.0664 - root_mean_squared_error: 0.0868 - mean_squared_error: 0.0075 - val_loss: 0.0351 - val_mean_absolute_error: 0.1697 - val_root_mean_squared_error: 0.1873 - val_mean_squared_error: 0.0351
# Epoch 12/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0101 - mean_absolute_error: 0.0784 - root_mean_squared_error: 0.1004 - mean_squared_error: 0.01
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0100 - mean_absolute_error: 0.0781 - root_mean_squared_error: 0.1001 - mean_squared_error: 0.0100 - val_loss: 0.0085 - val_mean_absolute_error: 0.0672 - val_root_mean_squared_error: 0.0920 - val_mean_squared_error: 0.0085
# Epoch 13/25
# 9/9 [==============================] - 0s 988us/step loss: 0.0078 - mean_absolute_error: 0.0674 - root_mean_squared_error: 0.0882 - mean_squared_error: 0.00
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0077 - mean_absolute_error: 0.0670 - root_mean_squared_error: 0.0877 - mean_squared_error: 0.0077 - val_loss: 0.0137 - val_mean_absolute_error: 0.0954 - val_root_mean_squared_error: 0.1170 - val_mean_squared_error: 0.0137
# Epoch 14/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0090 - mean_absolute_error: 0.0711 - root_mean_squared_error: 0.0951 - mean_squared_error: 0.00
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0092 - mean_absolute_error: 0.0719 - root_mean_squared_error: 0.0959 - mean_squared_error: 0.0092 - val_loss: 0.0090 - val_mean_absolute_error: 0.0724 - val_root_mean_squared_error: 0.0949 - val_mean_squared_error: 0.0090
# Epoch 15/25
# 9/9 [==============================] - 0s 895us/step loss: 0.0082 - mean_absolute_error: 0.0687 - root_mean_squared_error: 0.0905 - mean_squared_error: 0.00
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0082 - mean_absolute_error: 0.0687 - root_mean_squared_error: 0.0904 - mean_squared_error: 0.0082 - val_loss: 0.0106 - val_mean_absolute_error: 0.0734 - val_root_mean_squared_error: 0.1028 - val_mean_squared_error: 0.0106
# Epoch 16/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0086 - mean_absolute_error: 0.0711 - root_mean_squared_error: 0.0927 - mean_squared_error: 0.00
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0086 - mean_absolute_error: 0.0715 - root_mean_squared_error: 0.0927 - mean_squared_error: 0.0086 - val_loss: 0.0092 - val_mean_absolute_error: 0.0681 - val_root_mean_squared_error: 0.0957 - val_mean_squared_error: 0.0092
# Epoch 17/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0068 - mean_absolute_error: 0.0617 - root_mean_squared_error: 0.0824 - mean_squared_error: 0.00
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0068 - mean_absolute_error: 0.0619 - root_mean_squared_error: 0.0825 - mean_squared_error: 0.0068 - val_loss: 0.0084 - val_mean_absolute_error: 0.0672 - val_root_mean_squared_error: 0.0918 - val_mean_squared_error: 0.0084
# Epoch 18/25
# 9/9 [==============================] - 0s 969us/step loss: 0.0073 - mean_absolute_error: 0.0646 - root_mean_squared_error: 0.0852 - mean_squared_error: 0.00
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0074 - mean_absolute_error: 0.0652 - root_mean_squared_error: 0.0862 - mean_squared_error: 0.0074 - val_loss: 0.0304 - val_mean_absolute_error: 0.1578 - val_root_mean_squared_error: 0.1743 - val_mean_squared_error: 0.0304
# Epoch 19/25
# 9/9 [==============================] - 0s 915us/step loss: 0.0081 - mean_absolute_error: 0.0695 - root_mean_squared_error: 0.0902 - mean_squared_error: 0.00
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0081 - mean_absolute_error: 0.0695 - root_mean_squared_error: 0.0902 - mean_squared_error: 0.0081 - val_loss: 0.0149 - val_mean_absolute_error: 0.0989 - val_root_mean_squared_error: 0.1221 - val_mean_squared_error: 0.0149
# Epoch 20/25
# 9/9 [==============================] - 0s 953us/step loss: 0.0070 - mean_absolute_error: 0.0632 - root_mean_squared_error: 0.0835 - mean_squared_error: 0.00
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0070 - mean_absolute_error: 0.0634 - root_mean_squared_error: 0.0835 - mean_squared_error: 0.0070 - val_loss: 0.0095 - val_mean_absolute_error: 0.0689 - val_root_mean_squared_error: 0.0976 - val_mean_squared_error: 0.0095
# Epoch 21/25
# 9/9 [==============================] - 0s 970us/step loss: 0.0083 - mean_absolute_error: 0.0700 - root_mean_squared_error: 0.0913 - mean_squared_error: 0.00
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0083 - mean_absolute_error: 0.0701 - root_mean_squared_error: 0.0914 - mean_squared_error: 0.0083 - val_loss: 0.0086 - val_mean_absolute_error: 0.0652 - val_root_mean_squared_error: 0.0926 - val_mean_squared_error: 0.0086
# Epoch 22/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0073 - mean_absolute_error: 0.0641 - root_mean_squared_error: 0.0853 - mean_squared_error: 0.00
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0073 - mean_absolute_error: 0.0640 - root_mean_squared_error: 0.0853 - mean_squared_error: 0.0073 - val_loss: 0.0092 - val_mean_absolute_error: 0.0697 - val_root_mean_squared_error: 0.0959 - val_mean_squared_error: 0.0092
# Epoch 23/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0071 - mean_absolute_error: 0.0626 - root_mean_squared_error: 0.0840 - mean_squared_error: 0.00
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0071 - mean_absolute_error: 0.0627 - root_mean_squared_error: 0.0840 - mean_squared_error: 0.0071 - val_loss: 0.0098 - val_mean_absolute_error: 0.0717 - val_root_mean_squared_error: 0.0990 - val_mean_squared_error: 0.0098
# Epoch 24/25
# 9/9 [==============================] - 0s 903us/step loss: 0.0072 - mean_absolute_error: 0.0645 - root_mean_squared_error: 0.0851 - mean_squared_error: 0.00
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0073 - mean_absolute_error: 0.0646 - root_mean_squared_error: 0.0852 - mean_squared_error: 0.0073 - val_loss: 0.0123 - val_mean_absolute_error: 0.0842 - val_root_mean_squared_error: 0.1108 - val_mean_squared_error: 0.0123
# Epoch 25/25
# 9/9 [==============================] - 0s 939us/step loss: 0.0076 - mean_absolute_error: 0.0677 - root_mean_squared_error: 0.0873 - mean_squared_error: 0.00
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0077 - mean_absolute_error: 0.0678 - root_mean_squared_error: 0.0876 - mean_squared_error: 0.0077 - val_loss: 0.0139 - val_mean_absolute_error: 0.0885 - val_root_mean_squared_error: 0.1180 - val_mean_squared_error: 0.0139

# %%
time_took_to_run = sum(cb.logs)
print(time_took_to_run)
# Out:
# 10.814449585974216

# %%
# Predict using the trained model
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)
# Out:
# 33/33 [==============================] - 0s 905us/step
# 9/9 [==============================] - 0s 949us/step

# %%
# Evaluate the model on training and testing data
train_rmse = np.sqrt(mean_squared_error(y_train, train_predictions))
test_rmse = np.sqrt(mean_squared_error(y_test, test_predictions))
evaluation = model.evaluate(X_test, y_test)
print(f'Training RMSE: {train_rmse}')
print("Testing RMSE: " + str(evaluation[2]))
print("MSE (validation): " + str(evaluation[0]))
print("MAE (validation): " + str(evaluation[1]))
print("R2 (validation): " + str(r2_score(y_true=y_test, y_pred=test_predictions)))
# Out:
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0139 - mean_absolute_error: 0.0885 - root_mean_squared_error: 0.1180 - mean_squared_error: 0.0139
# Training RMSE: 0.11044235462116823
# Testing RMSE: 0.11800917237997055
# MSE (validation): 0.01392616517841816
# MAE (validation): 0.08847029507160187
# R2 (validation): 0.6726051669852078

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(mse, label="Mean Squared Error")
plt.title('MSE Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(mae, label="Mean Squared Error")
plt.title('MAE Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(rmse, label="Root Mean Squared Error")
plt.title('RMSE Per Epoch')
plt.xlabel('Epoch')
plt.xlim(1,25)
plt.ylabel('RMSE')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(r2, label="R2 Score")
plt.title('R2 Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('R2')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(scaler.inverse_transform(test_predictions.reshape(-1,1)), label="Predictions")
plt.plot(scaler.inverse_transform(y_test.reshape(-1,1)), label="Actual")
plt.title('Predictions vs. Actual')
plt.xlabel("Month")
plt.ylabel("Avg Temperature")
plt.legend()
