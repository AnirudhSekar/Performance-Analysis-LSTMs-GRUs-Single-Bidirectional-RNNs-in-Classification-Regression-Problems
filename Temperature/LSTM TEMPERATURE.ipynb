# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_squared_error
from sklearn import metrics
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import tensorflow as tf
import os
from timeit import default_timer as timer
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
# Load the dataset
weather_data = pd.read_csv("../austin_weather.csv")

# Display the first few rows of the dataset
print(weather_data.head())
# Out:
#          Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0  2013-12-21         74        60        45            67           49
# 1  2013-12-22         56        48        39            43           36
# 2  2013-12-23         58        45        32            31           27
# 3  2013-12-24         61        46        31            36           28
# 4  2013-12-25         58        50        41            44           40
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  ...  \
# 0           43                  93                 75                 57  ...
# 1           28                  93                 68                 43  ...
# 2           23                  76                 52                 27  ...
# 3           21                  89                 56                 22  ...
# 4           36                  86                 71                 56  ...
#
#   SeaLevelPressureAvgInches SeaLevelPressureLowInches VisibilityHighMiles  \
# 0                     29.68                     29.59                  10
# 1                     30.13                     29.87                  10
# 2                     30.49                     30.41                  10
# 3                     30.45                      30.3                  10
# 4                     30.33                     30.27                  10
#
#   VisibilityAvgMiles VisibilityLowMiles WindHighMPH WindAvgMPH WindGustMPH  \
# 0                  7                  2          20          4          31
# 1                 10                  5          16          6          25
# 2                 10                 10           8          3          12
# 3                 10                  7          12          4          20
# 4                 10                  7          10          2          16
#
#   PrecipitationSumInches               Events
# 0                   0.46  Rain , Thunderstorm
# 1                      0
# 2                      0
# 3                      0
# 4                      T
#
# [5 rows x 21 columns]

# %%
# Extract the 'TempAvgF' column as a time series
temperature_series = weather_data['TempAvgF'].values.astype(float)

print(len(temperature_series))
# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
temperature_series_scaled = scaler.fit_transform(temperature_series.reshape(-1, 1))
# Out:
# 1319

# %%
# Plot the time series data
plt.figure(figsize=(10, 6))
plt.plot(temperature_series, label='Austin Temperature')
plt.title('Austin Temperature Time Series')
plt.xlabel('Month')
plt.ylabel('Avg Temperature')
plt.legend()
plt.show()

# %%
# Function to create the dataset with input features and labels
def create_dataset(series, look_back=1):
    X, y = [], []
    for i in range(len(series) - look_back):
        X.append(series[i:(i + look_back), 0])
        y.append(series[i + look_back, 0])
    return np.array(X), np.array(y)

# %%
look_back = 7  # You can experiment with different values
X, y = create_dataset(temperature_series_scaled, look_back)

# Reshape input to be [samples, time steps, features]
X = np.reshape(X, (X.shape[0], X.shape[1], 1))


# Split the data into training and testing sets
train_size = int(len(X) * 0.8)
test_size = len(X) - train_size
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
mse = []
mae = []  
rmse = []
r2 = []
class PredictionCallback(tf.keras.callbacks.Callback):    
  def on_epoch_end(self, epoch, logs={}):
    y_pred = self.model.predict(X_test)
    # Evaluate the model on training and testing data
    test_rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
    rmse.append(test_rmse)
    mse.append(metrics.mean_squared_error(y_test, y_pred))
    mae.append((metrics.mean_absolute_error(y_test, y_pred)))
    r2.append(metrics.r2_score(y_test, y_pred))

# %%
class Model_Timer(tf.keras.callbacks.Callback):
    def __init__(self):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

# %%
model = Sequential([
    LSTM(units=50, return_sequences=True),
    LSTM(units=50, return_sequences=True),
    LSTM(units=50, return_sequences=True),
    LSTM(units=50),
    Dense(units=1)
])
cb = Model_Timer()
# Compile the model
model.compile(optimizer=tf.optimizers.legacy.Adam(learning_rate=0.001), loss="mse", metrics=["MeanAbsoluteError","RootMeanSquaredError", "MeanSquaredError"])
model.fit(X_train, y_train, batch_size=8, epochs=25, validation_data=(X_test, y_test),callbacks=[PredictionCallback(), cb])
# Out:
# Epoch 1/25
# 9/9 [==============================] - 1s 2ms/step - loss: 0.0474 - mean_absolute_error: 0.1538 - root_mean_squared_error: 0.2176 - mean_squared_error: 0.04
# 132/132 [==============================] - 4s 14ms/step - loss: 0.0468 - mean_absolute_error: 0.1525 - root_mean_squared_error: 0.2162 - mean_squared_error: 0.0468 - val_loss: 0.0187 - val_mean_absolute_error: 0.1041 - val_root_mean_squared_error: 0.1367 - val_mean_squared_error: 0.0187
# Epoch 2/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0147 - mean_absolute_error: 0.0934 - root_mean_squared_error: 0.1212 - mean_squared_error: 0.01
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0147 - mean_absolute_error: 0.0936 - root_mean_squared_error: 0.1211 - mean_squared_error: 0.0147 - val_loss: 0.0182 - val_mean_absolute_error: 0.1010 - val_root_mean_squared_error: 0.1351 - val_mean_squared_error: 0.0182
# Epoch 3/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0147 - mean_absolute_error: 0.0944 - root_mean_squared_error: 0.1211 - mean_squared_error: 0.01
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0147 - mean_absolute_error: 0.0945 - root_mean_squared_error: 0.1213 - mean_squared_error: 0.0147 - val_loss: 0.0213 - val_mean_absolute_error: 0.1196 - val_root_mean_squared_error: 0.1460 - val_mean_squared_error: 0.0213
# Epoch 4/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0154 - mean_absolute_error: 0.0973 - root_mean_squared_error: 0.1242 - mean_squared_error: 0.01
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0154 - mean_absolute_error: 0.0970 - root_mean_squared_error: 0.1239 - mean_squared_error: 0.0154 - val_loss: 0.0194 - val_mean_absolute_error: 0.1092 - val_root_mean_squared_error: 0.1394 - val_mean_squared_error: 0.0194
# Epoch 5/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0136 - mean_absolute_error: 0.0887 - root_mean_squared_error: 0.1168 - mean_squared_error: 0.01
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0139 - mean_absolute_error: 0.0900 - root_mean_squared_error: 0.1177 - mean_squared_error: 0.0139 - val_loss: 0.0188 - val_mean_absolute_error: 0.0992 - val_root_mean_squared_error: 0.1373 - val_mean_squared_error: 0.0188
# Epoch 6/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0142 - mean_absolute_error: 0.0920 - root_mean_squared_error: 0.1190 - mean_squared_error: 0.01
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0141 - mean_absolute_error: 0.0919 - root_mean_squared_error: 0.1188 - mean_squared_error: 0.0141 - val_loss: 0.0175 - val_mean_absolute_error: 0.0998 - val_root_mean_squared_error: 0.1323 - val_mean_squared_error: 0.0175
# Epoch 7/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0138 - mean_absolute_error: 0.0903 - root_mean_squared_error: 0.1174 - mean_squared_error: 0.01
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0137 - mean_absolute_error: 0.0899 - root_mean_squared_error: 0.1170 - mean_squared_error: 0.0137 - val_loss: 0.0195 - val_mean_absolute_error: 0.1108 - val_root_mean_squared_error: 0.1397 - val_mean_squared_error: 0.0195
# Epoch 8/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0137 - mean_absolute_error: 0.0893 - root_mean_squared_error: 0.1172 - mean_squared_error: 0.01
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0136 - mean_absolute_error: 0.0892 - root_mean_squared_error: 0.1165 - mean_squared_error: 0.0136 - val_loss: 0.0177 - val_mean_absolute_error: 0.1006 - val_root_mean_squared_error: 0.1330 - val_mean_squared_error: 0.0177
# Epoch 9/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0145 - mean_absolute_error: 0.0941 - root_mean_squared_error: 0.1203 - mean_squared_error: 0.01
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0143 - mean_absolute_error: 0.0934 - root_mean_squared_error: 0.1194 - mean_squared_error: 0.0143 - val_loss: 0.0195 - val_mean_absolute_error: 0.1043 - val_root_mean_squared_error: 0.1396 - val_mean_squared_error: 0.0195
# Epoch 10/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0136 - mean_absolute_error: 0.0895 - root_mean_squared_error: 0.1164 - mean_squared_error: 0.01
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0135 - mean_absolute_error: 0.0891 - root_mean_squared_error: 0.1160 - mean_squared_error: 0.0135 - val_loss: 0.0172 - val_mean_absolute_error: 0.0957 - val_root_mean_squared_error: 0.1310 - val_mean_squared_error: 0.0172
# Epoch 11/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0129 - mean_absolute_error: 0.0867 - root_mean_squared_error: 0.1135 - mean_squared_error: 0.01
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0130 - mean_absolute_error: 0.0871 - root_mean_squared_error: 0.1140 - mean_squared_error: 0.0130 - val_loss: 0.0200 - val_mean_absolute_error: 0.1136 - val_root_mean_squared_error: 0.1415 - val_mean_squared_error: 0.0200
# Epoch 12/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0129 - mean_absolute_error: 0.0880 - root_mean_squared_error: 0.1134 - mean_squared_error: 0.01
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0130 - mean_absolute_error: 0.0879 - root_mean_squared_error: 0.1138 - mean_squared_error: 0.0130 - val_loss: 0.0163 - val_mean_absolute_error: 0.0975 - val_root_mean_squared_error: 0.1278 - val_mean_squared_error: 0.0163
# Epoch 13/25
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0123 - mean_absolute_error: 0.0859 - root_mean_squared_error: 0.1111 - mean_squared_error: 0.01
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0125 - mean_absolute_error: 0.0864 - root_mean_squared_error: 0.1118 - mean_squared_error: 0.0125 - val_loss: 0.0168 - val_mean_absolute_error: 0.0988 - val_root_mean_squared_error: 0.1297 - val_mean_squared_error: 0.0168
# Epoch 14/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0122 - mean_absolute_error: 0.0846 - root_mean_squared_error: 0.1103 - mean_squared_error: 0.01
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0118 - mean_absolute_error: 0.0832 - root_mean_squared_error: 0.1087 - mean_squared_error: 0.0118 - val_loss: 0.0153 - val_mean_absolute_error: 0.0899 - val_root_mean_squared_error: 0.1237 - val_mean_squared_error: 0.0153
# Epoch 15/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0110 - mean_absolute_error: 0.0797 - root_mean_squared_error: 0.1050 - mean_squared_error: 0.01
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0110 - mean_absolute_error: 0.0797 - root_mean_squared_error: 0.1049 - mean_squared_error: 0.0110 - val_loss: 0.0134 - val_mean_absolute_error: 0.0833 - val_root_mean_squared_error: 0.1158 - val_mean_squared_error: 0.0134
# Epoch 16/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0096 - mean_absolute_error: 0.0739 - root_mean_squared_error: 0.0978 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0097 - mean_absolute_error: 0.0752 - root_mean_squared_error: 0.0987 - mean_squared_error: 0.0097 - val_loss: 0.0156 - val_mean_absolute_error: 0.1070 - val_root_mean_squared_error: 0.1249 - val_mean_squared_error: 0.0156
# Epoch 17/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0083 - mean_absolute_error: 0.0687 - root_mean_squared_error: 0.0912 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0083 - mean_absolute_error: 0.0685 - root_mean_squared_error: 0.0909 - mean_squared_error: 0.0083 - val_loss: 0.0088 - val_mean_absolute_error: 0.0691 - val_root_mean_squared_error: 0.0940 - val_mean_squared_error: 0.0088
# Epoch 18/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0076 - mean_absolute_error: 0.0660 - root_mean_squared_error: 0.0871 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0076 - mean_absolute_error: 0.0660 - root_mean_squared_error: 0.0871 - mean_squared_error: 0.0076 - val_loss: 0.0103 - val_mean_absolute_error: 0.0756 - val_root_mean_squared_error: 0.1013 - val_mean_squared_error: 0.0103
# Epoch 19/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0660 - root_mean_squared_error: 0.0865 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0075 - mean_absolute_error: 0.0660 - root_mean_squared_error: 0.0865 - mean_squared_error: 0.0075 - val_loss: 0.0084 - val_mean_absolute_error: 0.0659 - val_root_mean_squared_error: 0.0915 - val_mean_squared_error: 0.0084
# Epoch 20/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0075 - mean_absolute_error: 0.0658 - root_mean_squared_error: 0.0866 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0076 - mean_absolute_error: 0.0661 - root_mean_squared_error: 0.0869 - mean_squared_error: 0.0076 - val_loss: 0.0078 - val_mean_absolute_error: 0.0652 - val_root_mean_squared_error: 0.0884 - val_mean_squared_error: 0.0078
# Epoch 21/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0065 - mean_absolute_error: 0.0589 - root_mean_squared_error: 0.0804 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0066 - mean_absolute_error: 0.0599 - root_mean_squared_error: 0.0812 - mean_squared_error: 0.0066 - val_loss: 0.0098 - val_mean_absolute_error: 0.0819 - val_root_mean_squared_error: 0.0988 - val_mean_squared_error: 0.0098
# Epoch 22/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0639 - root_mean_squared_error: 0.0851 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0071 - mean_absolute_error: 0.0633 - root_mean_squared_error: 0.0845 - mean_squared_error: 0.0071 - val_loss: 0.0086 - val_mean_absolute_error: 0.0720 - val_root_mean_squared_error: 0.0926 - val_mean_squared_error: 0.0086
# Epoch 23/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0066 - mean_absolute_error: 0.0593 - root_mean_squared_error: 0.0810 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0066 - mean_absolute_error: 0.0594 - root_mean_squared_error: 0.0813 - mean_squared_error: 0.0066 - val_loss: 0.0081 - val_mean_absolute_error: 0.0648 - val_root_mean_squared_error: 0.0899 - val_mean_squared_error: 0.0081
# Epoch 24/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0069 - mean_absolute_error: 0.0619 - root_mean_squared_error: 0.0829 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0068 - mean_absolute_error: 0.0617 - root_mean_squared_error: 0.0825 - mean_squared_error: 0.0068 - val_loss: 0.0084 - val_mean_absolute_error: 0.0716 - val_root_mean_squared_error: 0.0918 - val_mean_squared_error: 0.0084
# Epoch 25/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0067 - mean_absolute_error: 0.0606 - root_mean_squared_error: 0.0816 - mean_squared_error: 0.00
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0067 - mean_absolute_error: 0.0607 - root_mean_squared_error: 0.0820 - mean_squared_error: 0.0067 - val_loss: 0.0080 - val_mean_absolute_error: 0.0647 - val_root_mean_squared_error: 0.0893 - val_mean_squared_error: 0.0080

# %%
time_took_to_run = sum(cb.logs)
print(time_took_to_run)
# Out:
# 20.01417925208807

# %%
# Predict using the trained model
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)
# Out:
# 33/33 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 1ms/step

# %%
# Evaluate the model on training and testing data
train_rmse = np.sqrt(mean_squared_error(y_train, train_predictions))
test_rmse = np.sqrt(mean_squared_error(y_test, test_predictions))
evaluation = model.evaluate(X_test, y_test)
print(f'Training RMSE: {train_rmse}')
print("Testing RMSE: " + str(evaluation[2]))
print("MSE (validation): " + str(evaluation[0]))
print("MAE (validation): " + str(evaluation[1]))
print("R2 (validation): " + str(r2_score(y_true=y_test, y_pred=test_predictions)))
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0080 - mean_absolute_error: 0.0647 - root_mean_squared_error: 0.0893 - mean_squared_error: 0.0080
# Training RMSE: 0.07796538176304028
# Testing RMSE: 0.08931683748960495
# MSE (validation): 0.007977496832609177
# MAE (validation): 0.06471606343984604
# R2 (validation): 0.8124544531491371

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(mse, label="Mean Squared Error")
plt.title('MSE Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(mae, label="Mean Squared Error")
plt.title('MAE Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(rmse, label="Root Mean Squared Error")
plt.title('RMSE Per Epoch')
plt.xlabel('Epoch')
plt.xlim(1,25)
plt.ylabel('RMSE')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(r2, label="R2 Score")
plt.title('R2 Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('R2')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(scaler.inverse_transform(test_predictions.reshape(-1,1)), label="Predictions")
plt.plot(scaler.inverse_transform(y_test.reshape(-1,1)), label="Actual")
plt.title('Predictions vs. Actual')
plt.xlabel("Month")
plt.ylabel("Avg Temperature")
plt.legend()
