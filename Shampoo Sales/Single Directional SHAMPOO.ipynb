# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN
import tensorflow as tf
import os
from timeit import default_timer as timer
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
# Load the dataset
shampoo_data = pd.read_csv("../shampoo_sales.csv")

# Display the first few rows of the dataset
print(shampoo_data.head())
# Out:
#   Month  Sales
# 0  1-01  266.0
# 1  1-02  145.9
# 2  1-03  183.1
# 3  1-04  119.3
# 4  1-05  180.3

# %%
shampoo_series = shampoo_data['Sales'].values.astype(float)


# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
shampoo_series_scaled = scaler.fit_transform(shampoo_series.reshape(-1, 1))

# %%
# Plot the time series data
plt.figure(figsize=(10, 6))
plt.plot(shampoo_series, label='Shampoo Sales')
plt.title('Shampoo Sales Time Series')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.legend()
plt.show()

# %%
# Function to create the dataset with input features and labels
def create_dataset(series, look_back=1):
    X, y = [], []
    for i in range(len(series) - look_back):
        X.append(series[i:(i + look_back), 0])
        y.append(series[i + look_back, 0])
    return np.array(X), np.array(y)

# %%
look_back = 7  # You can experiment with different values
X, y = create_dataset(shampoo_series_scaled, look_back)

# Reshape input to be [samples, time steps, features]
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

# Split the data into training and testing sets
train_size = int(len(X) * 0.8)
test_size = len(X) - train_size
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
mse = []
mae = []  
rmse = []
r2 = []
class PredictionCallback(tf.keras.callbacks.Callback):    
  def on_epoch_end(self, epoch, logs={}):
    y_pred = self.model.predict(X_test)
    index = []

    # Evaluate the model on training and testing data
    test_rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
    rmse.append(test_rmse)
    mse.append(metrics.mean_squared_error(y_test, y_pred))
    mae.append((metrics.mean_absolute_error(y_test, y_pred)))
    r2.append(metrics.r2_score(y_test, y_pred))

# %%
class Model_Timer(tf.keras.callbacks.Callback):
    def __init__(self):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

# %%
model = Sequential([
    SimpleRNN(units=50, return_sequences=True, input_shape=(X.shape[1], 1)),
    SimpleRNN(units=50, return_sequences=True),
    SimpleRNN(units=50, return_sequences=True),
    SimpleRNN(units=50),
    Dense(units=1)
])

cb = Model_Timer()
# Compile the model
model.compile(optimizer=tf.optimizers.legacy.Adam(learning_rate=0.001), loss="mse", metrics=["MeanAbsoluteError","RootMeanSquaredError", "MeanSquaredError"])
model.fit(X_train, y_train, batch_size=8, epochs=25, validation_data=(X_test, y_test),callbacks=[PredictionCallback(), cb])
# Out:
# Epoch 1/25
# 1/1 [==============================] - 0s 162ms/steps: 0.3087 - mean_absolute_error: 0.5028 - root_mean_squared_error: 0.5556 - mean_squared_error: 0.30
# 3/3 [==============================] - 1s 192ms/step - loss: 0.1797 - mean_absolute_error: 0.3823 - root_mean_squared_error: 0.4239 - mean_squared_error: 0.1797 - val_loss: 0.0674 - val_mean_absolute_error: 0.2267 - val_root_mean_squared_error: 0.2597 - val_mean_squared_error: 0.0674
# Epoch 2/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0997 - mean_absolute_error: 0.2763 - root_mean_squared_error: 0.3157 - mean_squared_error: 0.09
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0863 - mean_absolute_error: 0.2488 - root_mean_squared_error: 0.2938 - mean_squared_error: 0.0863 - val_loss: 0.3989 - val_mean_absolute_error: 0.6025 - val_root_mean_squared_error: 0.6316 - val_mean_squared_error: 0.3989
# Epoch 3/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0634 - mean_absolute_error: 0.2023 - root_mean_squared_error: 0.2518 - mean_squared_error: 0.06
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0442 - mean_absolute_error: 0.1665 - root_mean_squared_error: 0.2103 - mean_squared_error: 0.0442 - val_loss: 0.0673 - val_mean_absolute_error: 0.2259 - val_root_mean_squared_error: 0.2594 - val_mean_squared_error: 0.0673
# Epoch 4/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0252 - mean_absolute_error: 0.1370 - root_mean_squared_error: 0.1586 - mean_squared_error: 0.02
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0363 - mean_absolute_error: 0.1569 - root_mean_squared_error: 0.1905 - mean_squared_error: 0.0363 - val_loss: 0.0552 - val_mean_absolute_error: 0.2017 - val_root_mean_squared_error: 0.2349 - val_mean_squared_error: 0.0552
# Epoch 5/25
# 1/1 [==============================] - 0s 8ms/steposs: 0.0217 - mean_absolute_error: 0.1112 - root_mean_squared_error: 0.1472 - mean_squared_error: 0.02
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0178 - mean_absolute_error: 0.1113 - root_mean_squared_error: 0.1333 - mean_squared_error: 0.0178 - val_loss: 0.1459 - val_mean_absolute_error: 0.3347 - val_root_mean_squared_error: 0.3819 - val_mean_squared_error: 0.1459
# Epoch 6/25
# 1/1 [==============================] - 0s 8ms/steposs: 0.0144 - mean_absolute_error: 0.0947 - root_mean_squared_error: 0.1201 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0252 - mean_absolute_error: 0.1273 - root_mean_squared_error: 0.1589 - mean_squared_error: 0.0252 - val_loss: 0.1282 - val_mean_absolute_error: 0.3106 - val_root_mean_squared_error: 0.3580 - val_mean_squared_error: 0.1282
# Epoch 7/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0189 - mean_absolute_error: 0.1036 - root_mean_squared_error: 0.1375 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0143 - mean_absolute_error: 0.0929 - root_mean_squared_error: 0.1194 - mean_squared_error: 0.0143 - val_loss: 0.0588 - val_mean_absolute_error: 0.2109 - val_root_mean_squared_error: 0.2425 - val_mean_squared_error: 0.0588
# Epoch 8/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0309 - mean_absolute_error: 0.1540 - root_mean_squared_error: 0.1757 - mean_squared_error: 0.03
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0181 - mean_absolute_error: 0.1097 - root_mean_squared_error: 0.1347 - mean_squared_error: 0.0181 - val_loss: 0.0889 - val_mean_absolute_error: 0.2585 - val_root_mean_squared_error: 0.2982 - val_mean_squared_error: 0.0889
# Epoch 9/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0168 - mean_absolute_error: 0.1033 - root_mean_squared_error: 0.1295 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0139 - mean_absolute_error: 0.0975 - root_mean_squared_error: 0.1178 - mean_squared_error: 0.0139 - val_loss: 0.1543 - val_mean_absolute_error: 0.3537 - val_root_mean_squared_error: 0.3928 - val_mean_squared_error: 0.1543
# Epoch 10/25
# 1/1 [==============================] - 0s 8ms/steposs: 0.0028 - mean_absolute_error: 0.0510 - root_mean_squared_error: 0.0532 - mean_squared_error: 0.00
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0145 - mean_absolute_error: 0.1044 - root_mean_squared_error: 0.1206 - mean_squared_error: 0.0145 - val_loss: 0.1378 - val_mean_absolute_error: 0.3270 - val_root_mean_squared_error: 0.3712 - val_mean_squared_error: 0.1378
# Epoch 11/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0132 - mean_absolute_error: 0.1001 - root_mean_squared_error: 0.1148 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0127 - mean_absolute_error: 0.0943 - root_mean_squared_error: 0.1125 - mean_squared_error: 0.0127 - val_loss: 0.0806 - val_mean_absolute_error: 0.2471 - val_root_mean_squared_error: 0.2839 - val_mean_squared_error: 0.0806
# Epoch 12/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0160 - mean_absolute_error: 0.1129 - root_mean_squared_error: 0.1266 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0123 - mean_absolute_error: 0.0884 - root_mean_squared_error: 0.1111 - mean_squared_error: 0.0123 - val_loss: 0.1041 - val_mean_absolute_error: 0.2793 - val_root_mean_squared_error: 0.3226 - val_mean_squared_error: 0.1041
# Epoch 13/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0147 - mean_absolute_error: 0.1075 - root_mean_squared_error: 0.1213 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0105 - mean_absolute_error: 0.0861 - root_mean_squared_error: 0.1026 - mean_squared_error: 0.0105 - val_loss: 0.1373 - val_mean_absolute_error: 0.3173 - val_root_mean_squared_error: 0.3706 - val_mean_squared_error: 0.1373
# Epoch 14/25
# 1/1 [==============================] - 0s 8ms/steposs: 0.0152 - mean_absolute_error: 0.1101 - root_mean_squared_error: 0.1233 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0106 - mean_absolute_error: 0.0864 - root_mean_squared_error: 0.1028 - mean_squared_error: 0.0106 - val_loss: 0.1035 - val_mean_absolute_error: 0.2782 - val_root_mean_squared_error: 0.3218 - val_mean_squared_error: 0.1035
# Epoch 15/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0127 - mean_absolute_error: 0.0982 - root_mean_squared_error: 0.1127 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0079 - mean_absolute_error: 0.0703 - root_mean_squared_error: 0.0887 - mean_squared_error: 0.0079 - val_loss: 0.0940 - val_mean_absolute_error: 0.2652 - val_root_mean_squared_error: 0.3067 - val_mean_squared_error: 0.0940
# Epoch 16/25
# 1/1 [==============================] - 0s 8ms/steposs: 0.0102 - mean_absolute_error: 0.0841 - root_mean_squared_error: 0.1012 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0080 - mean_absolute_error: 0.0701 - root_mean_squared_error: 0.0895 - mean_squared_error: 0.0080 - val_loss: 0.1023 - val_mean_absolute_error: 0.2757 - val_root_mean_squared_error: 0.3198 - val_mean_squared_error: 0.1023
# Epoch 17/25
# 1/1 [==============================] - 0s 8ms/steposs: 0.0099 - mean_absolute_error: 0.0751 - root_mean_squared_error: 0.0994 - mean_squared_error: 0.00
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0076 - mean_absolute_error: 0.0693 - root_mean_squared_error: 0.0871 - mean_squared_error: 0.0076 - val_loss: 0.1002 - val_mean_absolute_error: 0.2729 - val_root_mean_squared_error: 0.3166 - val_mean_squared_error: 0.1002
# Epoch 18/25
# 1/1 [==============================] - 0s 8ms/steposs: 0.0079 - mean_absolute_error: 0.0772 - root_mean_squared_error: 0.0887 - mean_squared_error: 0.00
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0073 - mean_absolute_error: 0.0704 - root_mean_squared_error: 0.0853 - mean_squared_error: 0.0073 - val_loss: 0.1015 - val_mean_absolute_error: 0.2742 - val_root_mean_squared_error: 0.3186 - val_mean_squared_error: 0.1015
# Epoch 19/25
# 1/1 [==============================] - 0s 8ms/steposs: 0.0115 - mean_absolute_error: 0.0934 - root_mean_squared_error: 0.1071 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0067 - mean_absolute_error: 0.0662 - root_mean_squared_error: 0.0820 - mean_squared_error: 0.0067 - val_loss: 0.0925 - val_mean_absolute_error: 0.2618 - val_root_mean_squared_error: 0.3042 - val_mean_squared_error: 0.0925
# Epoch 20/25
# 1/1 [==============================] - 0s 8ms/steposs: 0.0125 - mean_absolute_error: 0.0979 - root_mean_squared_error: 0.1119 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0067 - mean_absolute_error: 0.0654 - root_mean_squared_error: 0.0820 - mean_squared_error: 0.0067 - val_loss: 0.0937 - val_mean_absolute_error: 0.2631 - val_root_mean_squared_error: 0.3061 - val_mean_squared_error: 0.0937
# Epoch 21/25
# 1/1 [==============================] - 0s 8ms/steposs: 0.0079 - mean_absolute_error: 0.0771 - root_mean_squared_error: 0.0886 - mean_squared_error: 0.00
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0068 - mean_absolute_error: 0.0669 - root_mean_squared_error: 0.0827 - mean_squared_error: 0.0068 - val_loss: 0.1024 - val_mean_absolute_error: 0.2745 - val_root_mean_squared_error: 0.3200 - val_mean_squared_error: 0.1024
# Epoch 22/25
# 1/1 [==============================] - 0s 8ms/steposs: 0.0040 - mean_absolute_error: 0.0475 - root_mean_squared_error: 0.0631 - mean_squared_error: 0.00
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0067 - mean_absolute_error: 0.0662 - root_mean_squared_error: 0.0817 - mean_squared_error: 0.0067 - val_loss: 0.0938 - val_mean_absolute_error: 0.2625 - val_root_mean_squared_error: 0.3063 - val_mean_squared_error: 0.0938
# Epoch 23/25
# 1/1 [==============================] - 0s 8ms/steposs: 0.0048 - mean_absolute_error: 0.0567 - root_mean_squared_error: 0.0694 - mean_squared_error: 0.00
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0068 - mean_absolute_error: 0.0674 - root_mean_squared_error: 0.0828 - mean_squared_error: 0.0068 - val_loss: 0.1056 - val_mean_absolute_error: 0.2779 - val_root_mean_squared_error: 0.3250 - val_mean_squared_error: 0.1056
# Epoch 24/25
# 1/1 [==============================] - 0s 8ms/steposs: 0.0042 - mean_absolute_error: 0.0551 - root_mean_squared_error: 0.0649 - mean_squared_error: 0.00
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0065 - mean_absolute_error: 0.0653 - root_mean_squared_error: 0.0805 - mean_squared_error: 0.0065 - val_loss: 0.0936 - val_mean_absolute_error: 0.2611 - val_root_mean_squared_error: 0.3060 - val_mean_squared_error: 0.0936
# Epoch 25/25
# 1/1 [==============================] - 0s 8ms/steposs: 0.0045 - mean_absolute_error: 0.0484 - root_mean_squared_error: 0.0669 - mean_squared_error: 0.00
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0063 - mean_absolute_error: 0.0625 - root_mean_squared_error: 0.0791 - mean_squared_error: 0.0063 - val_loss: 0.1047 - val_mean_absolute_error: 0.2759 - val_root_mean_squared_error: 0.3236 - val_mean_squared_error: 0.1047

# %%
time_took_to_run = sum(cb.logs)
print(time_took_to_run)
# Out:
# 2.156040835659951

# %%
# Predict using the trained model
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 9ms/step

# %%
# Evaluate the model on training and testing data
train_rmse = np.sqrt(mean_squared_error(y_train, train_predictions))
test_rmse = np.sqrt(mean_squared_error(y_test, test_predictions))
print(f'Training RMSE: {train_rmse}')
print(f"Testing RMSE: {test_rmse}")
print("MSE (validation): " + str(mean_squared_error(y_test, test_predictions)))
print("MAE (validation): " + str(mean_absolute_error(y_test, test_predictions)))
print(f"R2 Validation: {metrics.r2_score(y_test, test_predictions)}" )
# Out:
# Training RMSE: 0.07490532799594714
# Testing RMSE: 0.32362352508806735
# MSE (validation): 0.10473218599042695
# MAE (validation): 0.27591653271126354
# R2 Validation: -2.717858816544893

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(mse, label="Mean Squared Error")
plt.title('MSE Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(mae, label="Mean Absolute Error")
plt.title('MAE Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(rmse, label="Root Mean Squared Error")
plt.title('RMSE Per Epoch')
plt.xlabel('Epoch')
plt.xlim(1,25)
plt.ylabel('RMSE')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(r2, label="R2 Score")
plt.title('R2 Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('R2')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(scaler.inverse_transform(test_predictions.reshape(-1,1)), label="Predictions")
plt.plot(scaler.inverse_transform(y_test.reshape(-1,1)), label="Actual")
plt.title('Predictions vs. Actual')
plt.xlabel("Month")
plt.ylabel("Sales")
plt.legend()
