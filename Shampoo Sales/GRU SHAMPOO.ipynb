# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU
import tensorflow as tf
import os
from timeit import default_timer as timer

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
# Load the dataset
shampoo_data = pd.read_csv("../shampoo_sales.csv")

# Display the first few rows of the dataset
print(shampoo_data.head())
# Out:
#   Month  Sales
# 0  1-01  266.0
# 1  1-02  145.9
# 2  1-03  183.1
# 3  1-04  119.3
# 4  1-05  180.3

# %%
shampoo_series = shampoo_data['Sales'].values.astype(float)


# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
shampoo_series_scaled = scaler.fit_transform(shampoo_series.reshape(-1, 1))

# %%
# Plot the time series data
plt.figure(figsize=(10, 6))
plt.plot(shampoo_series, label='Shampoo Sales')
plt.title('Shampoo Sales Time Series')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.legend()
plt.show()

# %%
# Function to create the dataset with input features and labels
def create_dataset(series, look_back=1):
    X, y = [], []
    for i in range(len(series) - look_back):
        X.append(series[i:(i + look_back), 0])
        y.append(series[i + look_back, 0])
    return np.array(X), np.array(y)

# %%
look_back = 7  # You can experiment with different values
X, y = create_dataset(shampoo_series_scaled, look_back)

# Reshape input to be [samples, time steps, features]
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

# Split the data into training and testing sets
train_size = int(len(X) * 0.8)
test_size = len(X) - train_size
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
mse = []
mae = []  
rmse = []
r2 = []
class PredictionCallback(tf.keras.callbacks.Callback):    
  def on_epoch_end(self, epoch, logs={}):
    y_pred = self.model.predict(X_test)
    index = []

    # Evaluate the model on training and testing data
    test_rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
    rmse.append(test_rmse)
    mse.append(metrics.mean_squared_error(y_test, y_pred))
    mae.append((metrics.mean_absolute_error(y_test, y_pred)))
    r2.append(metrics.r2_score(y_test, y_pred))

# %%
class Model_Timer(tf.keras.callbacks.Callback):
    def __init__(self):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

# %%
model = Sequential([
    GRU(units=50, return_sequences=True, input_shape=(X.shape[1], 1)),
    GRU(units=50, return_sequences=True),
    GRU(units=50, return_sequences=True),
    GRU(units=50),
    Dense(units=1)
])

cb = Model_Timer()
# Compile the model
model.compile(optimizer=tf.optimizers.legacy.Adam(learning_rate=0.001), loss="mse", metrics=["MeanAbsoluteError","RootMeanSquaredError", "MeanSquaredError"])
model.fit(X_train, y_train, batch_size=8, epochs=25, validation_data=(X_test, y_test),callbacks=[PredictionCallback(), cb])
# Out:
# Epoch 1/25
# 1/1 [==============================] - 1s 560ms/steps: 0.1588 - mean_absolute_error: 0.3704 - root_mean_squared_error: 0.3984 - mean_squared_error: 0.15
# 3/3 [==============================] - 3s 554ms/step - loss: 0.0927 - mean_absolute_error: 0.2528 - root_mean_squared_error: 0.3044 - mean_squared_error: 0.0927 - val_loss: 0.3437 - val_mean_absolute_error: 0.5633 - val_root_mean_squared_error: 0.5863 - val_mean_squared_error: 0.3437
# Epoch 2/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0656 - mean_absolute_error: 0.2167 - root_mean_squared_error: 0.2561 - mean_squared_error: 0.06
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0368 - mean_absolute_error: 0.1560 - root_mean_squared_error: 0.1919 - mean_squared_error: 0.0368 - val_loss: 0.1076 - val_mean_absolute_error: 0.2877 - val_root_mean_squared_error: 0.3281 - val_mean_squared_error: 0.1076
# Epoch 3/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0254 - mean_absolute_error: 0.1372 - root_mean_squared_error: 0.1593 - mean_squared_error: 0.02
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0193 - mean_absolute_error: 0.1166 - root_mean_squared_error: 0.1389 - mean_squared_error: 0.0193 - val_loss: 0.0503 - val_mean_absolute_error: 0.1850 - val_root_mean_squared_error: 0.2243 - val_mean_squared_error: 0.0503
# Epoch 4/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0377 - mean_absolute_error: 0.1734 - root_mean_squared_error: 0.1942 - mean_squared_error: 0.03
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0257 - mean_absolute_error: 0.1336 - root_mean_squared_error: 0.1604 - mean_squared_error: 0.0257 - val_loss: 0.0835 - val_mean_absolute_error: 0.2427 - val_root_mean_squared_error: 0.2890 - val_mean_squared_error: 0.0835
# Epoch 5/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0148 - mean_absolute_error: 0.1031 - root_mean_squared_error: 0.1215 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0171 - mean_absolute_error: 0.1089 - root_mean_squared_error: 0.1308 - mean_squared_error: 0.0171 - val_loss: 0.1321 - val_mean_absolute_error: 0.3275 - val_root_mean_squared_error: 0.3634 - val_mean_squared_error: 0.1321
# Epoch 6/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0128 - mean_absolute_error: 0.0916 - root_mean_squared_error: 0.1130 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0181 - mean_absolute_error: 0.1101 - root_mean_squared_error: 0.1344 - mean_squared_error: 0.0181 - val_loss: 0.1474 - val_mean_absolute_error: 0.3501 - val_root_mean_squared_error: 0.3839 - val_mean_squared_error: 0.1474
# Epoch 7/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0329 - mean_absolute_error: 0.1614 - root_mean_squared_error: 0.1813 - mean_squared_error: 0.03
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0187 - mean_absolute_error: 0.1135 - root_mean_squared_error: 0.1366 - mean_squared_error: 0.0187 - val_loss: 0.1078 - val_mean_absolute_error: 0.2885 - val_root_mean_squared_error: 0.3283 - val_mean_squared_error: 0.1078
# Epoch 8/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0187 - mean_absolute_error: 0.1089 - root_mean_squared_error: 0.1369 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0159 - mean_absolute_error: 0.1058 - root_mean_squared_error: 0.1262 - mean_squared_error: 0.0159 - val_loss: 0.0704 - val_mean_absolute_error: 0.2184 - val_root_mean_squared_error: 0.2653 - val_mean_squared_error: 0.0704
# Epoch 9/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0142 - mean_absolute_error: 0.1057 - root_mean_squared_error: 0.1190 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0145 - mean_absolute_error: 0.0991 - root_mean_squared_error: 0.1204 - mean_squared_error: 0.0145 - val_loss: 0.0532 - val_mean_absolute_error: 0.1867 - val_root_mean_squared_error: 0.2307 - val_mean_squared_error: 0.0532
# Epoch 10/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0145 - mean_absolute_error: 0.1006 - root_mean_squared_error: 0.1205 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0137 - mean_absolute_error: 0.0943 - root_mean_squared_error: 0.1172 - mean_squared_error: 0.0137 - val_loss: 0.0504 - val_mean_absolute_error: 0.1795 - val_root_mean_squared_error: 0.2245 - val_mean_squared_error: 0.0504
# Epoch 11/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0129 - mean_absolute_error: 0.0961 - root_mean_squared_error: 0.1137 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0123 - mean_absolute_error: 0.0898 - root_mean_squared_error: 0.1111 - mean_squared_error: 0.0123 - val_loss: 0.0561 - val_mean_absolute_error: 0.1895 - val_root_mean_squared_error: 0.2368 - val_mean_squared_error: 0.0561
# Epoch 12/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0160 - mean_absolute_error: 0.1084 - root_mean_squared_error: 0.1264 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0120 - mean_absolute_error: 0.0894 - root_mean_squared_error: 0.1096 - mean_squared_error: 0.0120 - val_loss: 0.0426 - val_mean_absolute_error: 0.1666 - val_root_mean_squared_error: 0.2064 - val_mean_squared_error: 0.0426
# Epoch 13/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0075 - mean_absolute_error: 0.0722 - root_mean_squared_error: 0.0864 - mean_squared_error: 0.00
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0112 - mean_absolute_error: 0.0861 - root_mean_squared_error: 0.1061 - mean_squared_error: 0.0112 - val_loss: 0.0294 - val_mean_absolute_error: 0.1413 - val_root_mean_squared_error: 0.1715 - val_mean_squared_error: 0.0294
# Epoch 14/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0131 - mean_absolute_error: 0.0916 - root_mean_squared_error: 0.1144 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0119 - mean_absolute_error: 0.0876 - root_mean_squared_error: 0.1092 - mean_squared_error: 0.0119 - val_loss: 0.0254 - val_mean_absolute_error: 0.1371 - val_root_mean_squared_error: 0.1594 - val_mean_squared_error: 0.0254
# Epoch 15/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0131 - mean_absolute_error: 0.0874 - root_mean_squared_error: 0.1144 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0112 - mean_absolute_error: 0.0840 - root_mean_squared_error: 0.1060 - mean_squared_error: 0.0112 - val_loss: 0.0267 - val_mean_absolute_error: 0.1371 - val_root_mean_squared_error: 0.1634 - val_mean_squared_error: 0.0267
# Epoch 16/25
# 1/1 [==============================] - 0s 10ms/stepss: 0.0075 - mean_absolute_error: 0.0757 - root_mean_squared_error: 0.0866 - mean_squared_error: 0.00
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0112 - mean_absolute_error: 0.0843 - root_mean_squared_error: 0.1059 - mean_squared_error: 0.0112 - val_loss: 0.0267 - val_mean_absolute_error: 0.1372 - val_root_mean_squared_error: 0.1634 - val_mean_squared_error: 0.0267
# Epoch 17/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0049 - mean_absolute_error: 0.0623 - root_mean_squared_error: 0.0702 - mean_squared_error: 0.00
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0114 - mean_absolute_error: 0.0852 - root_mean_squared_error: 0.1069 - mean_squared_error: 0.0114 - val_loss: 0.0262 - val_mean_absolute_error: 0.1373 - val_root_mean_squared_error: 0.1619 - val_mean_squared_error: 0.0262
# Epoch 18/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0058 - mean_absolute_error: 0.0634 - root_mean_squared_error: 0.0758 - mean_squared_error: 0.00
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0112 - mean_absolute_error: 0.0848 - root_mean_squared_error: 0.1060 - mean_squared_error: 0.0112 - val_loss: 0.0257 - val_mean_absolute_error: 0.1374 - val_root_mean_squared_error: 0.1604 - val_mean_squared_error: 0.0257
# Epoch 19/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0154 - mean_absolute_error: 0.1061 - root_mean_squared_error: 0.1242 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0112 - mean_absolute_error: 0.0842 - root_mean_squared_error: 0.1059 - mean_squared_error: 0.0112 - val_loss: 0.0261 - val_mean_absolute_error: 0.1372 - val_root_mean_squared_error: 0.1617 - val_mean_squared_error: 0.0261
# Epoch 20/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0044 - mean_absolute_error: 0.0599 - root_mean_squared_error: 0.0661 - mean_squared_error: 0.00
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0112 - mean_absolute_error: 0.0851 - root_mean_squared_error: 0.1060 - mean_squared_error: 0.0112 - val_loss: 0.0268 - val_mean_absolute_error: 0.1371 - val_root_mean_squared_error: 0.1636 - val_mean_squared_error: 0.0268
# Epoch 21/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0077 - mean_absolute_error: 0.0642 - root_mean_squared_error: 0.0875 - mean_squared_error: 0.00
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0114 - mean_absolute_error: 0.0854 - root_mean_squared_error: 0.1069 - mean_squared_error: 0.0114 - val_loss: 0.0340 - val_mean_absolute_error: 0.1520 - val_root_mean_squared_error: 0.1844 - val_mean_squared_error: 0.0340
# Epoch 22/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0111 - mean_absolute_error: 0.0778 - root_mean_squared_error: 0.1052 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0114 - mean_absolute_error: 0.0864 - root_mean_squared_error: 0.1068 - mean_squared_error: 0.0114 - val_loss: 0.0328 - val_mean_absolute_error: 0.1501 - val_root_mean_squared_error: 0.1811 - val_mean_squared_error: 0.0328
# Epoch 23/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0077 - mean_absolute_error: 0.0662 - root_mean_squared_error: 0.0880 - mean_squared_error: 0.00
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0113 - mean_absolute_error: 0.0868 - root_mean_squared_error: 0.1062 - mean_squared_error: 0.0113 - val_loss: 0.0325 - val_mean_absolute_error: 0.1498 - val_root_mean_squared_error: 0.1804 - val_mean_squared_error: 0.0325
# Epoch 24/25
# 1/1 [==============================] - 0s 9ms/steposs: 0.0102 - mean_absolute_error: 0.0819 - root_mean_squared_error: 0.1012 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0110 - mean_absolute_error: 0.0854 - root_mean_squared_error: 0.1051 - mean_squared_error: 0.0110 - val_loss: 0.0325 - val_mean_absolute_error: 0.1495 - val_root_mean_squared_error: 0.1803 - val_mean_squared_error: 0.0325
# Epoch 25/25
# 1/1 [==============================] - 0s 11ms/stepss: 0.0157 - mean_absolute_error: 0.1048 - root_mean_squared_error: 0.1253 - mean_squared_error: 0.01
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0111 - mean_absolute_error: 0.0855 - root_mean_squared_error: 0.1052 - mean_squared_error: 0.0111 - val_loss: 0.0330 - val_mean_absolute_error: 0.1500 - val_root_mean_squared_error: 0.1817 - val_mean_squared_error: 0.0330

# %%
time_took_to_run = sum(cb.logs)
print(time_took_to_run)
# Out:
# 4.553116705734283

# %%
# Predict using the trained model
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step

# %%
# Evaluate the model on training and testing data
train_rmse = np.sqrt(mean_squared_error(y_train, train_predictions))
test_rmse = np.sqrt(mean_squared_error(y_test, test_predictions))
print(f'Training RMSE: {train_rmse}')
print(f"Testing RMSE: {test_rmse}")
print("MSE (validation): " + str(mean_squared_error(y_test, test_predictions)))
print("MAE (validation): " + str(mean_absolute_error(y_test, test_predictions)))
print(f"R2 Validation: {metrics.r2_score(y_test, test_predictions)}" )
# Out:
# Training RMSE: 0.10497987104671432
# Testing RMSE: 0.18173292775693936
# MSE (validation): 0.03302685703110894
# MAE (validation): 0.14997045092444003
# R2 Validation: -0.17241123571219652

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(mse, label="Mean Squared Error")
plt.title('MSE Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(mae, label="Mean Absolute Error")
plt.title('MAE Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(rmse, label="Root Mean Squared Error")
plt.title('RMSE Per Epoch')
plt.xlabel('Epoch')
plt.xlim(1,25)
plt.ylabel('RMSE')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(r2, label="R2 Score")
plt.title('R2 Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('R2')
plt.legend()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(scaler.inverse_transform(test_predictions.reshape(-1,1)), label="Predictions")
plt.plot(scaler.inverse_transform(y_test.reshape(-1,1)), label="Actual")
plt.title('Predictions vs. Actual')
plt.xlabel("Month")
plt.ylabel("Sales")
plt.legend()
